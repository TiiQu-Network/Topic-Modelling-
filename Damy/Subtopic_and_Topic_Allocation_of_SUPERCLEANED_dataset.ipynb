# %%
import pandas as pd
import numpy as np
import string
import scipy
import sklearn
import spacy
import nltk
import re
import os

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import cosine_similarity
#from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer, util

# %%
def read_csv_files_in_folder(folder_path):
    """
    Read all CSV files in a folder and concatenate them into a single DataFrame.

    Parameters:
    - folder_path (str): Path to the folder containing CSV files.

    Returns:
    - pd.DataFrame: Concatenated DataFrame.
    """
    # List all files in the folder
    all_files = os.listdir(folder_path)

    # List to store DataFrames
    dfs = []

    # Loop through CSV files and read them
    for file in all_files:
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            dfs.append(df)

    # Concatenate DataFrames into one
    concatenated_df = pd.concat(dfs, ignore_index=True)
    
    return concatenated_df

# %%
def text_embed(text_col_name, dataframe, vector_col_name):
    model = SentenceTransformer("thenlper/gte-small")
    dataframe[text_col_name] = dataframe[text_col_name].astype(str)
    dataframe[vector_col_name] = dataframe[text_col_name].apply(lambda x: model.encode(x))
    return dataframe

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Function to find the matching label for each corpus
def match_corpus_to_label(corpus_embedding, label_embeddings, threshold=0.85):
    similarities = cosine_similarity([corpus_embedding], label_embeddings)
    max_similarity = np.max(similarities)
    
    if max_similarity >= threshold:
        # Get the index of the matching label
        label_index = np.argmax(similarities)
        return label_index
    else:
        return None

# %%
# Set random seed for reproducibility
np.random.seed(42)

def assign_subtopic(corpus_df, corpus_embeddings, subtopic_df, subtopic_embeddings, subtopic_index_reference, subtopic_output):
    # Iterate over each row in sample_data
    for index, row in corpus_df.iterrows():
        corpus_embedding = row[corpus_embeddings]  # Assuming 'QA_vector' is the column with corpus embeddings
    
        # If the embedding is a sequence or array, stack them vertically and compute the mean
        if isinstance(corpus_embedding, list):
            corpus_embedding = np.mean(np.vstack(corpus_embedding), axis=0)

        # If the embedding is still 2D, flatten it to 1D
        if len(corpus_embedding.shape) > 1:
            corpus_embedding = corpus_embedding.flatten()

        matching_label_index = match_corpus_to_label(corpus_embedding, np.vstack(subtopic_embeddings.values))

        # If a matching label is found, assign it to a new column 'AssignedLabel'
        if matching_label_index is not None:
            corpus_df.at[index, subtopic_output] = subtopic_df.at[matching_label_index, subtopic_index_reference]

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove numbers, symbols, and punctuation (except for the case where 2 follows CO)
    text = re.sub(r'[\d' + re.escape(string.punctuation) + '](?<![cC][oO]2)', '', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Join the tokens back into a single string
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %% [markdown]
# # SMART CITIES

# %%
smart_cities_df = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\Supercleaned demo dataset ready for Topic mod 21 03.xlsx", 
                       sheet_name=1)
smart_cities_df
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6578  Smart Cities   What is the projected trend of Indonesia's GDP...
# 6579  Smart Cities   How do landowners in India show preference het...
# 6580  Smart Cities   What is the purpose of SKI Jakarta Governor Re...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6577  The guidelines provided in the Proturan Enter ...
# 6578  According to O'Neill (2023), the Gross Domesti...
# 6579  According to Patel et al. (2020), landowners i...
# 6580  SKI Jakarta Governor Regulation Number 15 of 2...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6577                                         Management
# 6578                                           Analysis
# 6579                                           Analysis
# 6580                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6578  Smart urbanism, citizen-centric approaches and...
# 6579  Smart urbanism, citizen-centric approaches and...
# 6580  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  https://www.sciencedirect.com/science/article/...
# 6578  https://www.sciencedirect.com/science/article/...
# 6579  https://www.sciencedirect.com/science/article/...
# 6580  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6578  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6579  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6580  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
# [6582 rows x 7 columns]

# %%
smart_cities_df.columns
# Out:
# Index(['Macrotopic ', 'Question', 'Answer', 'Label', 'Source Title ',
#        'Source Url', 'Source Author '],
#       dtype='object')

# %%
smart_cities_df['QA'] = smart_cities_df['Question'] + ' ' + smart_cities_df['Answer']
smart_cities_df
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6578  Smart Cities   What is the projected trend of Indonesia's GDP...
# 6579  Smart Cities   How do landowners in India show preference het...
# 6580  Smart Cities   What is the purpose of SKI Jakarta Governor Re...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6577  The guidelines provided in the Proturan Enter ...
# 6578  According to O'Neill (2023), the Gross Domesti...
# 6579  According to Patel et al. (2020), landowners i...
# 6580  SKI Jakarta Governor Regulation Number 15 of 2...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6577                                         Management
# 6578                                           Analysis
# 6579                                           Analysis
# 6580                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6578  Smart urbanism, citizen-centric approaches and...
# 6579  Smart urbanism, citizen-centric approaches and...
# 6580  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  https://www.sciencedirect.com/science/article/...
# 6578  https://www.sciencedirect.com/science/article/...
# 6579  https://www.sciencedirect.com/science/article/...
# 6580  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6578  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6579  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6580  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
#                                                      QA
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6578  What is the projected trend of Indonesia's GDP...
# 6579  How do landowners in India show preference het...
# 6580  What is the purpose of SKI Jakarta Governor Re...
# 6581  How does the implementation strategy of transi...
#
# [6582 rows x 8 columns]

# %%
# smart cities subtopic
folder_path = r'C:\Users\RedHat\Downloads\Tiiqu\Subtopics'
smcts_subtopic_df = read_csv_files_in_folder(folder_path)
smcts_subtopic_df
# Out:
#                                   Terminology  \
# 0       Sensor Networks for Urban Air Quality
# 1          IoT-enabled Air Quality Monitoring
# 2      Mobile Air Quality Monitoring Stations
# 3                 Real-time Pollution Mapping
# 4       Indoor Air Quality Monitoring Systems
# ..                                        ...
# 595                         Smart Water Grids
# 596  Weather Forecasting for Water Management
# 597  Community-based Water Quality Monitoring
# 598           Water Infrastructure Resilience
# 599    Mobile Apps for Reporting Water Issues
#
#                                            Description  \
# 0    Sensor networks for urban air quality refer to...
# 1    IoT-enabled Air Quality Monitoring refers to t...
# 2    Mobile Air Quality Monitoring Stations refer t...
# 3    Real-time Pollution Mapping refers to the proc...
# 4    Indoor Air Quality Monitoring Systems refer to...
# ..                                                 ...
# 595  A Smart Water Grid refers to the integration o...
# 596  Weather forecasting for water management refer...
# 597  Community-based Water Quality Monitoring refer...
# 598  Water Infrastructure Resilience refers to the ...
# 599  Mobile Apps for Reporting Water Issues refers ...
#
#                                               Keywords
# 0    Sensors, Air Quality, Urban, Monitoring, Pollu...
# 1    IoT, Air Quality Monitoring, Real-Time Data, S...
# 2    Mobile, Air, Quality, Monitoring, Stations, Se...
# 3    Real-time, Pollution, Mapping, Geospatial, Tra...
# 4    Indoor Air Quality, Monitoring Systems, Air Qu...
# ..                                                 ...
# 595  Smart Water Grid, IoT, Data Analytics, Artific...
# 596  Weather Forecasting, Water Management, Meteoro...
# 597  Community, Water Quality, Monitoring, Sustaina...
# 598  Resilience, Water Infrastructure, Disruption, ...
# 599  Reporting, Water Issues, Mobile Apps, Citizen ...
#
# [600 rows x 3 columns]

# %%
# text embedding for smart cities
text_embed('QA', smart_cities_df, 'QA_vector')
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6578  Smart Cities   What is the projected trend of Indonesia's GDP...
# 6579  Smart Cities   How do landowners in India show preference het...
# 6580  Smart Cities   What is the purpose of SKI Jakarta Governor Re...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6577  The guidelines provided in the Proturan Enter ...
# 6578  According to O'Neill (2023), the Gross Domesti...
# 6579  According to Patel et al. (2020), landowners i...
# 6580  SKI Jakarta Governor Regulation Number 15 of 2...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6577                                         Management
# 6578                                           Analysis
# 6579                                           Analysis
# 6580                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6578  Smart urbanism, citizen-centric approaches and...
# 6579  Smart urbanism, citizen-centric approaches and...
# 6580  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  https://www.sciencedirect.com/science/article/...
# 6578  https://www.sciencedirect.com/science/article/...
# 6579  https://www.sciencedirect.com/science/article/...
# 6580  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6578  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6579  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6580  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
#                                                      QA  \
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6578  What is the projected trend of Indonesia's GDP...
# 6579  How do landowners in India show preference het...
# 6580  What is the purpose of SKI Jakarta Governor Re...
# 6581  How does the implementation strategy of transi...
#
#                                               QA_vector
# 0     [-0.012195684, 0.007873172, 0.006466941, 0.029...
# 1     [-0.019286802, 0.043021444, 0.012284794, -0.01...
# 2     [-0.02020133, 0.025334762, -0.002407805, -0.01...
# 3     [-0.051888514, 0.01082537, 0.017671604, -0.043...
# 4     [-0.0022440273, -0.008420247, 0.017052963, -0....
# ...                                                 ...
# 6577  [-0.014814504, 0.00951411, 0.023957323, -0.050...
# 6578  [-0.05541449, -0.0032068617, 0.071445845, -0.0...
# 6579  [-0.005819576, 0.008612114, 0.025815105, -0.02...
# 6580  [-0.02840907, -0.032079037, 0.06578252, -0.069...
# 6581  [-0.015211115, -0.0051177023, 0.06099411, -0.0...
#
# [6582 rows x 9 columns]

# %%
# subtopic embedding for smart cities
text_embed('Description', smcts_subtopic_df, 'Des_vector')
# Out:
#                                   Terminology  \
# 0       Sensor Networks for Urban Air Quality
# 1          IoT-enabled Air Quality Monitoring
# 2      Mobile Air Quality Monitoring Stations
# 3                 Real-time Pollution Mapping
# 4       Indoor Air Quality Monitoring Systems
# ..                                        ...
# 595                         Smart Water Grids
# 596  Weather Forecasting for Water Management
# 597  Community-based Water Quality Monitoring
# 598           Water Infrastructure Resilience
# 599    Mobile Apps for Reporting Water Issues
#
#                                            Description  \
# 0    Sensor networks for urban air quality refer to...
# 1    IoT-enabled Air Quality Monitoring refers to t...
# 2    Mobile Air Quality Monitoring Stations refer t...
# 3    Real-time Pollution Mapping refers to the proc...
# 4    Indoor Air Quality Monitoring Systems refer to...
# ..                                                 ...
# 595  A Smart Water Grid refers to the integration o...
# 596  Weather forecasting for water management refer...
# 597  Community-based Water Quality Monitoring refer...
# 598  Water Infrastructure Resilience refers to the ...
# 599  Mobile Apps for Reporting Water Issues refers ...
#
#                                               Keywords  \
# 0    Sensors, Air Quality, Urban, Monitoring, Pollu...
# 1    IoT, Air Quality Monitoring, Real-Time Data, S...
# 2    Mobile, Air, Quality, Monitoring, Stations, Se...
# 3    Real-time, Pollution, Mapping, Geospatial, Tra...
# 4    Indoor Air Quality, Monitoring Systems, Air Qu...
# ..                                                 ...
# 595  Smart Water Grid, IoT, Data Analytics, Artific...
# 596  Weather Forecasting, Water Management, Meteoro...
# 597  Community, Water Quality, Monitoring, Sustaina...
# 598  Resilience, Water Infrastructure, Disruption, ...
# 599  Reporting, Water Issues, Mobile Apps, Citizen ...
#
#                                             Des_vector
# 0    [-0.032511596, -0.008433948, 0.06403352, -0.01...
# 1    [-0.019570377, -0.007127084, 0.05570755, -0.02...
# 2    [-0.016010625, 0.009993818, 0.063600145, -0.00...
# 3    [-0.030291691, -0.019748587, 0.058397368, -0.0...
# 4    [-0.018200023, -0.003171656, 0.051177938, -0.0...
# ..                                                 ...
# 595  [-0.013377284, 0.0023783373, 0.047986627, -0.0...
# 596  [-0.030780733, -0.030379986, 0.06936532, -0.00...
# 597  [-0.0028319797, -0.019709097, 0.024996435, -0....
# 598  [-0.023378167, -0.053442758, 0.027936874, -0.0...
# 599  [0.0036832225, -0.0105151, 0.053522613, -0.047...
#
# [600 rows x 4 columns]

# %%
# Subtopic assignment for smart cities dataset
assign_subtopic(smart_cities_df, 'QA_vector', smcts_subtopic_df, smcts_subtopic_df['Des_vector'], 'Terminology', 'Assigned Subtopic')

# %%
# PREPROCESSING

# %%
smart_cities_df['QA_prep'] = smart_cities_df['QA'].apply(preprocess_text)

# %%
smcts_subtopic_df['Des_prep'] = smcts_subtopic_df['Description'].apply(preprocess_text)

# %%
# text embedding for preprocessed smart cities corpus
text_embed('QA_prep', smart_cities_df, 'QA_prep_vector')
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6578  Smart Cities   What is the projected trend of Indonesia's GDP...
# 6579  Smart Cities   How do landowners in India show preference het...
# 6580  Smart Cities   What is the purpose of SKI Jakarta Governor Re...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6577  The guidelines provided in the Proturan Enter ...
# 6578  According to O'Neill (2023), the Gross Domesti...
# 6579  According to Patel et al. (2020), landowners i...
# 6580  SKI Jakarta Governor Regulation Number 15 of 2...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6577                                         Management
# 6578                                           Analysis
# 6579                                           Analysis
# 6580                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6578  Smart urbanism, citizen-centric approaches and...
# 6579  Smart urbanism, citizen-centric approaches and...
# 6580  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  https://www.sciencedirect.com/science/article/...
# 6578  https://www.sciencedirect.com/science/article/...
# 6579  https://www.sciencedirect.com/science/article/...
# 6580  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6578  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6579  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6580  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
#                                                      QA  \
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6578  What is the projected trend of Indonesia's GDP...
# 6579  How do landowners in India show preference het...
# 6580  What is the purpose of SKI Jakarta Governor Re...
# 6581  How does the implementation strategy of transi...
#
#                                               QA_vector  \
# 0     [-0.012195684, 0.007873172, 0.006466941, 0.029...
# 1     [-0.019286802, 0.043021444, 0.012284794, -0.01...
# 2     [-0.02020133, 0.025334762, -0.002407805, -0.01...
# 3     [-0.051888514, 0.01082537, 0.017671604, -0.043...
# 4     [-0.0022440273, -0.008420247, 0.017052963, -0....
# ...                                                 ...
# 6577  [-0.014814504, 0.00951411, 0.023957323, -0.050...
# 6578  [-0.05541449, -0.0032068617, 0.071445845, -0.0...
# 6579  [-0.005819576, 0.008612114, 0.025815105, -0.02...
# 6580  [-0.02840907, -0.032079037, 0.06578252, -0.069...
# 6581  [-0.015211115, -0.0051177023, 0.06099411, -0.0...
#
#                      Assigned Subtopic  \
# 0     Grid Voltage Stability Solutions
# 1            Waste-to-Energy Solutions
# 2         Renewable Energy Integration
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 6577                               NaN
# 6578                               NaN
# 6579                               NaN
# 6580                               NaN
# 6581   Efficient Public Transportation
#
#                                                 QA_prep  \
# 0     operational strategies like bid price control ...
# 1     purpose powertohydrogen ph technology ph techn...
# 2     ph contribute integration variable renewable e...
# 3     surplus alone insufficient economical px syste...
# 4     best route ph terms displacing diesel heavy co...
# ...                                                 ...
# 6577  proturan enter agrarian dan tata huangbaden pe...
# 6578  projected trend indonesias gdp per capita acco...
# 6579  landowners india show preference heterogeneity...
# 6580  purpose ski jakarta governor regulation number...
# 6581  implementation strategy transitoriented develo...
#
#                                          QA_prep_vector
# 0     [-0.022449002, 0.018022422, 0.009411752, 0.048...
# 1     [-0.026798876, 0.043908987, 0.032166984, -0.00...
# 2     [-0.052468862, 0.017500032, 0.029401012, -0.01...
# 3     [-0.054230493, 0.025611764, 0.034356646, -0.02...
# 4     [-0.013488555, -0.013958169, 0.04522113, -0.02...
# ...                                                 ...
# 6577  [-0.014260622, -0.010944142, 0.051180813, -0.0...
# 6578  [-0.041214325, 0.00021408785, 0.07849644, -0.0...
# 6579  [-0.019319465, 0.017689066, 0.02719766, -0.023...
# 6580  [-0.016116215, -0.017762946, 0.05998256, -0.06...
# 6581  [-0.025303632, -0.0066138757, 0.05601606, -0.0...
#
# [6582 rows x 12 columns]

# %%
# subtopic embedding for preprocessed smart cities description
text_embed('Des_prep', smcts_subtopic_df, 'Des_prep_vector')
# Out:
#                                   Terminology  \
# 0       Sensor Networks for Urban Air Quality
# 1          IoT-enabled Air Quality Monitoring
# 2      Mobile Air Quality Monitoring Stations
# 3                 Real-time Pollution Mapping
# 4       Indoor Air Quality Monitoring Systems
# ..                                        ...
# 595                         Smart Water Grids
# 596  Weather Forecasting for Water Management
# 597  Community-based Water Quality Monitoring
# 598           Water Infrastructure Resilience
# 599    Mobile Apps for Reporting Water Issues
#
#                                            Description  \
# 0    Sensor networks for urban air quality refer to...
# 1    IoT-enabled Air Quality Monitoring refers to t...
# 2    Mobile Air Quality Monitoring Stations refer t...
# 3    Real-time Pollution Mapping refers to the proc...
# 4    Indoor Air Quality Monitoring Systems refer to...
# ..                                                 ...
# 595  A Smart Water Grid refers to the integration o...
# 596  Weather forecasting for water management refer...
# 597  Community-based Water Quality Monitoring refer...
# 598  Water Infrastructure Resilience refers to the ...
# 599  Mobile Apps for Reporting Water Issues refers ...
#
#                                               Keywords  \
# 0    Sensors, Air Quality, Urban, Monitoring, Pollu...
# 1    IoT, Air Quality Monitoring, Real-Time Data, S...
# 2    Mobile, Air, Quality, Monitoring, Stations, Se...
# 3    Real-time, Pollution, Mapping, Geospatial, Tra...
# 4    Indoor Air Quality, Monitoring Systems, Air Qu...
# ..                                                 ...
# 595  Smart Water Grid, IoT, Data Analytics, Artific...
# 596  Weather Forecasting, Water Management, Meteoro...
# 597  Community, Water Quality, Monitoring, Sustaina...
# 598  Resilience, Water Infrastructure, Disruption, ...
# 599  Reporting, Water Issues, Mobile Apps, Citizen ...
#
#                                             Des_vector  \
# 0    [-0.032511596, -0.008433948, 0.06403352, -0.01...
# 1    [-0.019570377, -0.007127084, 0.05570755, -0.02...
# 2    [-0.016010625, 0.009993818, 0.063600145, -0.00...
# 3    [-0.030291691, -0.019748587, 0.058397368, -0.0...
# 4    [-0.018200023, -0.003171656, 0.051177938, -0.0...
# ..                                                 ...
# 595  [-0.013377284, 0.0023783373, 0.047986627, -0.0...
# 596  [-0.030780733, -0.030379986, 0.06936532, -0.00...
# 597  [-0.0028319797, -0.019709097, 0.024996435, -0....
# 598  [-0.023378167, -0.053442758, 0.027936874, -0.0...
# 599  [0.0036832225, -0.0105151, 0.053522613, -0.047...
#
#                                               Des_prep  \
# 0    sensor networks urban air quality refer use mu...
# 1    iotenabled air quality monitoring refers use i...
# 2    mobile air quality monitoring stations refer s...
# 3    realtime pollution mapping refers process trac...
# 4    indoor air quality monitoring systems refer de...
# ..                                                 ...
# 595  smart water grid refers integration advanced t...
# 596  weather forecasting water management refers us...
# 597  communitybased water quality monitoring refers...
# 598  water infrastructure resilience refers ability...
# 599  mobile apps reporting water issues refers soft...
#
#                                        Des_prep_vector
# 0    [-0.025221739, -0.002512642, 0.067848094, -0.0...
# 1    [-0.034565482, -0.006861557, 0.062069375, -0.0...
# 2    [-0.016696014, 0.007394806, 0.07728041, -0.001...
# 3    [-0.029291991, -0.011465249, 0.07051751, -0.01...
# 4    [-0.015027424, 0.017110107, 0.057737336, 0.000...
# ..                                                 ...
# 595  [-0.023247557, 0.007856621, 0.049678247, -0.01...
# 596  [-0.039074812, -0.04721483, 0.07345538, -0.004...
# 597  [-0.0035583482, -0.018783882, 0.06017778, -0.0...
# 598  [-0.026645694, -0.03607002, 0.034129072, -0.03...
# 599  [0.0059660925, -0.0022009364, 0.05279878, -0.0...
#
# [600 rows x 6 columns]

# %%
#Subtopic assignment for smart cities dataset
assign_subtopic(smart_cities_df, 'QA_prep_vector', smcts_subtopic_df, smcts_subtopic_df['Des_prep_vector'], 'Terminology', 'Assigned Subtopic(Preprocessed)')

# %%
smart_cities_df
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6578  Smart Cities   What is the projected trend of Indonesia's GDP...
# 6579  Smart Cities   How do landowners in India show preference het...
# 6580  Smart Cities   What is the purpose of SKI Jakarta Governor Re...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6577  The guidelines provided in the Proturan Enter ...
# 6578  According to O'Neill (2023), the Gross Domesti...
# 6579  According to Patel et al. (2020), landowners i...
# 6580  SKI Jakarta Governor Regulation Number 15 of 2...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6577                                         Management
# 6578                                           Analysis
# 6579                                           Analysis
# 6580                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6578  Smart urbanism, citizen-centric approaches and...
# 6579  Smart urbanism, citizen-centric approaches and...
# 6580  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  https://www.sciencedirect.com/science/article/...
# 6578  https://www.sciencedirect.com/science/article/...
# 6579  https://www.sciencedirect.com/science/article/...
# 6580  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6578  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6579  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6580  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
#                                                      QA  \
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6578  What is the projected trend of Indonesia's GDP...
# 6579  How do landowners in India show preference het...
# 6580  What is the purpose of SKI Jakarta Governor Re...
# 6581  How does the implementation strategy of transi...
#
#                                               QA_vector  \
# 0     [-0.012195684, 0.007873172, 0.006466941, 0.029...
# 1     [-0.019286802, 0.043021444, 0.012284794, -0.01...
# 2     [-0.02020133, 0.025334762, -0.002407805, -0.01...
# 3     [-0.051888514, 0.01082537, 0.017671604, -0.043...
# 4     [-0.0022440273, -0.008420247, 0.017052963, -0....
# ...                                                 ...
# 6577  [-0.014814504, 0.00951411, 0.023957323, -0.050...
# 6578  [-0.05541449, -0.0032068617, 0.071445845, -0.0...
# 6579  [-0.005819576, 0.008612114, 0.025815105, -0.02...
# 6580  [-0.02840907, -0.032079037, 0.06578252, -0.069...
# 6581  [-0.015211115, -0.0051177023, 0.06099411, -0.0...
#
#                      Assigned Subtopic  \
# 0     Grid Voltage Stability Solutions
# 1            Waste-to-Energy Solutions
# 2         Renewable Energy Integration
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 6577                               NaN
# 6578                               NaN
# 6579                               NaN
# 6580                               NaN
# 6581   Efficient Public Transportation
#
#                                                 QA_prep  \
# 0     operational strategies like bid price control ...
# 1     purpose powertohydrogen ph technology ph techn...
# 2     ph contribute integration variable renewable e...
# 3     surplus alone insufficient economical px syste...
# 4     best route ph terms displacing diesel heavy co...
# ...                                                 ...
# 6577  proturan enter agrarian dan tata huangbaden pe...
# 6578  projected trend indonesias gdp per capita acco...
# 6579  landowners india show preference heterogeneity...
# 6580  purpose ski jakarta governor regulation number...
# 6581  implementation strategy transitoriented develo...
#
#                                          QA_prep_vector  \
# 0     [-0.022449002, 0.018022422, 0.009411752, 0.048...
# 1     [-0.026798876, 0.043908987, 0.032166984, -0.00...
# 2     [-0.052468862, 0.017500032, 0.029401012, -0.01...
# 3     [-0.054230493, 0.025611764, 0.034356646, -0.02...
# 4     [-0.013488555, -0.013958169, 0.04522113, -0.02...
# ...                                                 ...
# 6577  [-0.014260622, -0.010944142, 0.051180813, -0.0...
# 6578  [-0.041214325, 0.00021408785, 0.07849644, -0.0...
# 6579  [-0.019319465, 0.017689066, 0.02719766, -0.023...
# 6580  [-0.016116215, -0.017762946, 0.05998256, -0.06...
# 6581  [-0.025303632, -0.0066138757, 0.05601606, -0.0...
#
#                         Assigned Subtopic(Preprocessed)
# 0                    Voltage and Reactive Power Control
# 1                         Grid-Connected Energy Storage
# 2                            Energy Storage Integration
# 3                           Energy Storage Optimization
# 4               Energy-efficient Transportation Systems
# ...                                                 ...
# 6577                        Public Transit Optimization
# 6578                                                NaN
# 6579                                                NaN
# 6580                                                NaN
# 6581  Integration with Urban Planning for Parking Op...
#
# [6582 rows x 13 columns]

# %%
# Export to CSV
smart_cities_df.to_csv('Smart Cities SUBTOPIC ALLOCATION with New Dataset---85percent.csv')

# %%
subs = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\Smart cities macro topic, topics, sub-topics.xlsx", sheet_name=1)
subs
# Out:
#                                  Urban Mobility  \
# 0                   Public Transit Optimization
# 1                      Micro-Mobility Solutions
# 2                       Traffic Flow Management
# 3            Intelligent Traffic Signal Systems
# 4            Pedestrian-Friendly Infrastructure
# 5                         Bike-sharing Programs
# 6             Multi-modal Transport Integration
# 7                         Smart Parking Systems
# 8                         Ride-sharing Services
# 9                   Traffic Congestion Modeling
# 10                       Last-Mile Connectivity
# 11                               Smart Highways
# 12               Connected Vehicle Technologies
# 13                 Mobility as a Service (MaaS)
# 14  Accessibility for Persons with Disabilities
# 15                         Carpooling Platforms
# 16             Real-time Transportation Updates
# 17                        Smart Toll Collection
# 18                         Hyperloop Technology
# 19              Electric Vehicle Infrastructure
# 20                       Traffic Data Analytics
# 21                       Dynamic Route Planning
# 22                  Traffic Incident Management
# 23                         Smart Commuting Apps
# 24                  Autonomous Public Transport
# 25                             Smart Crosswalks
# 26             Traffic Enforcement Technologies
# 27                  Traffic Simulation Modeling
# 28                           Urban Air Mobility
# 29         Smart Transportation Policy Planning
#
#             Intelligent Transportation Systems  \
# 0              Adaptive Traffic Signal Control
# 1    Vehicle-to-Everything (V2X) Communication
# 2   Cooperative Adaptive Cruise Control (CACC)
# 3                  Connected Vehicles Networks
# 4                 Traffic Surveillance Cameras
# 5            Incident Detection and Management
# 6        Real-time Traffic Information Systems
# 7                     Roadside Sensor Networks
# 8               Vehicle Detection Technologies
# 9               Smart Parking Guidance Systems
# 10                    Traffic Data Aggregation
# 11           Automated Toll Collection Systems
# 12                     Electronic Road Pricing
# 13                      Variable Message Signs
# 14             Intelligent Road Infrastructure
# 15        Traffic Flow Optimization Algorithms
# 16  Automated License Plate Recognition (ALPR)
# 17                     Dynamic Lane Management
# 18          Emergency Vehicle Priority Systems
# 19                 Predictive Traffic Modeling
# 20                Traveler Information Systems
# 21                  Traffic Management Centers
# 22           Intelligent Pedestrian Crosswalks
# 23       Smart Bus Rapid Transit (BRT) Systems
# 24                 Traffic Signal Coordination
# 25  Automated Public Transport Fare Collection
# 26                  Vehicle Platooning Systems
# 27             Smart Intersection Technologies
# 28   Smart Traffic Monitoring and Control Apps
# 29       Traffic Simulation and Modeling Tools
#
#                                        Smart Grids  \
# 0           Advanced Metering Infrastructure (AMI)
# 1                          Demand Response Systems
# 2                        Smart Metering Technology
# 3            Distribution Management Systems (DMS)
# 4                              Microgrid Solutions
# 5                   Grid Modernization Initiatives
# 6                       Energy Storage Integration
# 7                         Smart Grid Cybersecurity
# 8                     Renewable Energy Integration
# 9         Electric Vehicle Charging Infrastructure
# 10               Intelligent Substation Automation
# 11             Wide Area Monitoring Systems (WAMS)
# 12                Fault Detection and Localization
# 13              Voltage and Reactive Power Control
# 14                        Grid Resilience Planning
# 15                          Grid Edge Technologies
# 16               Smart Sensors for Grid Monitoring
# 17                             Grid Data Analytics
# 18   Distributed Energy Resources (DER) Management
# 19                      Transactive Energy Systems
# 20                    Grid Optimization Algorithms
# 21               Smart Grid Communication Networks
# 22                   Grid-Connected Energy Storage
# 23                           Grid Asset Management
# 24                       Energy Market Integration
# 25                     Virtual Power Plants (VPPs)
# 26                Grid Voltage Stability Solutions
# 27  Predictive Maintenance for Grid Infrastructure
# 28         Grid Reliability and Quality Monitoring
# 29              Integrated Volt-VAR Control (IVVC)
#
#                                     Energy Management  \
# 0                       Energy Consumption Monitoring
# 1                              Smart Grid Integration
# 2                              Demand-Side Management
# 3                           Automated Demand Response
# 4           Building Energy Management Systems (BEMS)
# 5                        Smart Home Energy Management
# 6                          Real-Time Energy Analytics
# 7                       Energy-Efficient HVAC Systems
# 8                          Predictive Energy Modeling
# 9                            Smart Lighting Solutions
# 10                        Renewable Energy Microgrids
# 11                        Energy Storage Optimization
# 12                        Virtual Power Plants (VPPs)
# 13               Smart Metering for Energy Efficiency
# 14      Distributed Energy Resources (DER) Management
# 15                      Energy Audit and Benchmarking
# 16                          Intelligent Load Shedding
# 17              Sustainable Urban Planning for Energy
# 18            Energy-efficient Transportation Systems
# 19                           Green Building Standards
# 20  Smart Charging Infrastructure for Electric Veh...
# 21                   Thermal Energy Storage Solutions
# 22              Energy-Efficient Industrial Processes
# 23                 Blockchain for Energy Transactions
# 24                     Energy Harvesting Technologies
# 25              Smart Water and Wastewater Management
# 26        Cognitive Buildings for Energy Optimization
# 27            Integration of IoT in Energy Management
# 28               Grid-Interactive Efficient Buildings
# 29       Energy Conservation Policies and Initiatives
#
#                         Sustainable Infrastructure  \
# 0                            Green Building Design
# 1              Eco-friendly Construction Materials
# 2                               Urban Green Spaces
# 3                     Low-Impact Development (LID)
# 4                           Smart Water Management
# 5              Sustainable Transportation Networks
# 6                   Intelligent Traffic Management
# 7                 Energy-Efficient Street Lighting
# 8                        Waste-to-Energy Solutions
# 9                       Circular Economy Practices
# 10                          Smart Waste Management
# 11          Resilient and Adaptable Infrastructure
# 12                      Sustainable Urban Planning
# 13                 Climate-Responsive Architecture
# 14                    Urban Heat Island Mitigation
# 15                           Green Roofs and Walls
# 16                 Efficient Public Transportation
# 17     Integrated Public and Active Transportation
# 18                   Stormwater Harvesting Systems
# 19                        Eco-district Development
# 20  Renewable Energy Integration in Infrastructure
# 21                  Smart Grids for Infrastructure
# 22                         Smart Parking Solutions
# 23                 Sustainable Materials Recycling
# 24                 Smart Infrastructure Monitoring
# 25                  Adaptive Infrastructure Design
# 26                        Microgrid Implementation
# 27                       Water-Saving Technologies
# 28   Sustainable Infrastructure Policy Development
# 29           Carbon-Neutral Construction Practices
#
#                                    Digital Governance  \
# 0                               E-Government Services
# 1                       Digital Citizen Participation
# 2                               Open Data Initiatives
# 3                          Civic Engagement Platforms
# 4                                  Smart City Portals
# 5                         Digital Identity Management
# 6                   Transparent Government Operations
# 7                         Cybersecurity in Governance
# 8                    Smart Legislation and Regulation
# 9                               Data Privacy Policies
# 10                         Digital Inclusion Programs
# 11                         Smart City Command Centers
# 12                     Cloud Computing for Governance
# 13                         Mobile Government Services
# 14                Blockchain in Public Administration
# 15                    Intelligent Document Management
# 16                            Online Service Delivery
# 17                          Smart Procurement Systems
# 18  Geospatial Information Systems (GIS) for Gover...
# 19                              Civic Tech Innovation
# 20            Collaborative Decision-Making Platforms
# 21            Social Media Integration for Governance
# 22                               Government Analytics
# 23                                   E-Voting Systems
# 24                     Smart Contracts for Governance
# 25        Real-Time Monitoring of Government Services
# 26                                 Virtual Town Halls
# 27              Artificial Intelligence in Governance
# 28           Predictive Analytics for Policy Planning
# 29                 Cyber-resilient Governance Systems
#
#                                     IoT in Cities  \
# 0                        Smart Sensors Deployment
# 1              IoT-enabled Smart Lighting Systems
# 2                 Connected Intelligent Buildings
# 3                        IoT in Urban Agriculture
# 4                          Smart Waste Management
# 5               Environmental Monitoring with IoT
# 6                         Smart Parking Solutions
# 7                      IoT for Traffic Management
# 8               Intelligent Public Transportation
# 9              IoT in Healthcare for Smart Cities
# 10                         Smart Water Management
# 11               IoT-based Air Quality Monitoring
# 12                  Asset Tracking and Management
# 13                Smart Grids and IoT Integration
# 14                     IoT in Energy Conservation
# 15                     Connected Street Furniture
# 16                    IoT for Disaster Management
# 17                       Smart Irrigation Systems
# 18  Industrial IoT (IIoT) for Smart Manufacturing
# 19               IoT in Retail for Smart Shopping
# 20                          Smart Home Automation
# 21                      IoT-enabled Public Safety
# 22              Wearable IoT Devices for Citizens
# 23          Real-time Weather Monitoring with IoT
# 24            IoT in Education for Smart Learning
# 25                     Connected Fleet Management
# 26                Precision Agriculture using IoT
# 27                 Smart Cameras and Surveillance
# 28                       IoT for Social Inclusion
# 29              Intelligent Waste Sorting Systems
#
#                                       Smart Buildings  \
# 0           Building Energy Management Systems (BEMS)
# 1                        Intelligent Lighting Systems
# 2                     Occupancy Sensors and Analytics
# 3   Smart HVAC (Heating, Ventilation, and Air Cond...
# 4           Automated Temperature and Climate Control
# 5                 Energy-Efficient Building Materials
# 6                     IoT-enabled Building Automation
# 7           Intelligent Fire Detection and Prevention
# 8                   Smart Security and Access Control
# 9                       Indoor Air Quality Monitoring
# 10                     Smart Elevators and Escalators
# 11        Predictive Maintenance for Building Systems
# 12                Building Information Modeling (BIM)
# 13          Renewable Energy Integration in Buildings
# 14                  Smart Windows and Shading Systems
# 15          Integrated Building Communication Systems
# 16                       Emergency Evacuation Systems
# 17                    Water Conservation in Buildings
# 18              Smart Parking Solutions for Buildings
# 19                        Sustainable Building Design
# 20                        Advanced Building Analytics
# 21  Remote Monitoring and Control of Building Systems
# 22                Sensor Networks for Building Health
# 23          Intelligent Waste Management in Buildings
# 24                     Smart Appliances and Equipment
# 25                          Adaptive Lighting Control
# 26                      Smart Meeting Room Management
# 27                         Virtual Concierge Services
# 28                      AI-driven Building Operations
# 29            Smart Home Integration within Buildings
#
#                                      Waste Management  \
# 0                        Smart Bin Monitoring Systems
# 1                          Waste Sorting Technologies
# 2                           RFID-based Waste Tracking
# 3                        IoT-enabled Waste Collection
# 4                  Automated Waste Collection Systems
# 5                    Intelligent Waste Disposal Units
# 6                          Waste-to-Energy Conversion
# 7                                Smart Recycling Bins
# 8                        E-waste Management Solutions
# 9                          Hazardous Waste Monitoring
# 10      Blockchain for Transparent Waste Transactions
# 11                  Real-time Monitoring of Landfills
# 12                           Smart Composting Systems
# 13              Municipal Solid Waste (MSW) Analytics
# 14             Reverse Vending Machines for Recycling
# 15                        Waste Segregation at Source
# 16                GPS-enabled Waste Collection Routes
# 17            Smart Fleet Management for Waste Trucks
# 18   Citizen Engagement Platforms for Waste Reduction
# 19     Circular Economy Practices in Waste Management
# 20                    Sustainable Packaging Solutions
# 21          Community-Based Waste Cleanup Initiatives
# 22              Data-driven Waste Management Policies
# 23                          Waste Reduction Campaigns
# 24  Public Awareness Programs on Responsible Disposal
# 25                 Smart Material Recovery Facilities
# 26                          Robotics in Waste Sorting
# 27           Advanced Analytics for Waste Forecasting
# 28              Smart Waste Bin Location Optimization
# 29          Mobile Apps for Reporting Illegal Dumping
#
#                                      Water Management  \
# 0                        Smart Water Metering Systems
# 1                IoT-enabled Water Quality Monitoring
# 2                       Leak Detection and Prevention
# 3                Automated Water Distribution Systems
# 4               Real-time Water Consumption Analytics
# 5                            Smart Irrigation Systems
# 6          Flood Prediction and Early Warning Systems
# 7                   Intelligent Stormwater Management
# 8                    Cloud-based Water Data Platforms
# 9                Water Conservation Apps for Citizens
# 10       Remote Sensing for Water Resource Assessment
# 11                  Smart Wastewater Treatment Plants
# 12      Sensor Networks for River and Lake Monitoring
# 13             Water Recycling and Reuse Technologies
# 14                   Water Scarcity Prediction Models
# 15                 Intelligent Water Pumping Stations
# 16      Blockchain for Transparent Water Transactions
# 17                        Aquifer Recharge Management
# 18  GIS (Geographic Information System) for Water ...
# 19           Real-time Monitoring of Reservoir Levels
# 20                  Data-driven Water Policy Planning
# 21            Smart Water Billing and Payment Systems
# 22           Citizen Engagement in Water Conservation
# 23               Sustainable Urban Planning for Water
# 24                          Desalination Technologies
# 25                                  Smart Water Grids
# 26           Weather Forecasting for Water Management
# 27           Community-based Water Quality Monitoring
# 28                    Water Infrastructure Resilience
# 29             Mobile Apps for Reporting Water Issues
#
#                                 Civic Engagement  \
# 0                Digital Participatory Platforms
# 1                    Crowdsourced Urban Planning
# 2            E-Government Services Accessibility
# 3                       Citizen Feedback Systems
# 4                 Community Decision-Making Apps
# 5   Open Data Initiatives for Civic Transparency
# 6                        Online Voting Platforms
# 7               Mobile Apps for Civic Engagement
# 8     Social Media Integration for Citizen Input
# 9                             Virtual Town Halls
# 10           Gamification of Civic Participation
# 11                      Civic Education Programs
# 12                    Public Consultation Forums
# 13                 Collaborative Budgeting Tools
# 14               Hackathons for Civic Innovation
# 15                   Citizen Science Initiatives
# 16                       Neighborhood Watch Apps
# 17                  Civic Crowdfunding Platforms
# 18            Smart City Dashboards for Citizens
# 19              Digital Civic Literacy Campaigns
# 20               Community-based Social Networks
# 21          Interactive Public Art Installations
# 22         Augmented Reality for Civic Awareness
# 23          IoT-enabled Citizen Feedback Devices
# 24        Geospatial Tools for Community Mapping
# 25                  Civic Hacktivism Initiatives
# 26                  Citizen Journalism Platforms
# 27        Civic Engagement Metrics and Analytics
# 28                Online Civic Training Programs
# 29    Youth Engagement Platforms in Smart Cities
#
#                                         Public Safety  \
# 0                          Emergency Response Systems
# 1                     Smart Surveillance Technologies
# 2                          Predictive Policing Models
# 3                             Real-time Crime Mapping
# 4                    Smart Street Lighting for Safety
# 5                                Public Safety Drones
# 6   Intelligent Traffic Management for Emergency V...
# 7                           Gunshot Detection Systems
# 8                  Wearable Tech for First Responders
# 9                Video Analytics for Crowd Monitoring
# 10         Automated License Plate Recognition (ALPR)
# 11                Smart Fire Detection and Prevention
# 12                            Community Policing Apps
# 13                   Biometric Identification Systems
# 14            Cybersecurity for Public Safety Systems
# 15               Public Health Emergency Preparedness
# 16      Smart Helmets for Police with AR capabilities
# 17                 Social Media Monitoring for Safety
# 18                          Safe City Command Centers
# 19   Flood and Natural Disaster Early Warning Systems
# 20           Smart Infrastructure Resilience Planning
# 21         Autonomous Vehicles for Emergency Response
# 22                     Gun Violence Prediction Models
# 23              AI-powered Emergency Dispatch Systems
# 24                    Location-based Emergency Alerts
# 25               Smart Public Transportation Security
# 26                    Surveillance-free Public Spaces
# 27                 Public Safety Training Simulations
# 28      Mobile Apps for Reporting Suspicious Activity
# 29                       Crisis Communication Systems
#
#                              Environmental Monitoring  \
# 0                      Air Quality Monitoring Systems
# 1                   IoT-enabled Environmental Sensors
# 2                              Smart Weather Stations
# 3                        Real-time Pollution Tracking
# 4                   Water Quality Monitoring Networks
# 5                              Soil Health Monitoring
# 6                             Biodiversity Monitoring
# 7                        Urban Heat Island Monitoring
# 8                          Noise Pollution Monitoring
# 9                        Radiation Monitoring Systems
# 10        Remote Sensing for Environmental Assessment
# 11  GIS (Geographic Information System) for Enviro...
# 12  Smart Grids for Energy Efficiency and Emission...
# 13                          Greenhouse Gas Monitoring
# 14                         Wildlife Tracking with IoT
# 15  Smart Agriculture Practices for Environmental ...
# 16              Environmental Impact Assessment Tools
# 17          Coastal and Marine Environment Monitoring
# 18  Sustainable Urban Planning for Environmental P...
# 19              Real-time Monitoring of Deforestation
# 20         Digital Twins for Environmental Simulation
# 21                   River and Lake Health Monitoring
# 22  Smart Pest Control with Minimal Environmental ...
# 23                       Environmental Data Analytics
# 24               Climate Change Adaptation Monitoring
# 25   Autonomous Drones for Environmental Surveillance
# 26   Mobile Apps for Reporting Environmental Concerns
# 27  Smart Waste Management for Environmental Susta...
# 28   Satellite Imaging for Environmental Observations
# 29  Citizen Science Initiatives for Environmental ...
#
#                              Urban Planning Analytics  \
# 0            Spatial Data Analysis for Urban Planning
# 1           Predictive Modeling for Population Growth
# 2   Traffic Flow Analytics for Transportation Plan...
# 3                           Land Use Pattern Analysis
# 4     Real-time Infrastructure Utilization Monitoring
# 5                          Demographic Data Analytics
# 6               Social and Economic Impact Assessment
# 7   GIS (Geographic Information System) for Urban ...
# 8                  Public Transit Ridership Analytics
# 9             Accessibility and Connectivity Modeling
# 10                          Urban Design Optimization
# 11                      Environmental Impact Analysis
# 12           Real-time Construction Project Analytics
# 13                Parking Demand and Supply Analytics
# 14                     Housing Affordability Analysis
# 15           Retail and Commercial Space Optimization
# 16                     Community Engagement Analytics
# 17          Public Health Analytics in Urban Planning
# 18                       Smart Zoning and Regulations
# 19                Green Space Allocation Optimization
# 20             Disaster Resilience Planning Analytics
# 21              Historical Urban Development Analysis
# 22           Cultural Heritage Preservation Analytics
# 23  Smart Growth and Sustainable Development Analy...
# 24    Crime Pattern Analysis for Safer Urban Planning
# 25                     Mixed-Use Development Planning
# 26                  Real Estate Market Trend Analysis
# 27              Noise and Air Quality Impact Analysis
# 28                Infrastructure Resilience Analytics
# 29                    Urban Mobility Pattern Analysis
#
#                                 Smart Street Lighting  \
# 0                     Intelligent LED Street Lighting
# 1                        Motion-Sensing Street Lights
# 2                         Adaptive Brightness Control
# 3                 IoT-enabled Street Light Monitoring
# 4                  Remote Management of Street Lights
# 5                       Solar-powered Street Lighting
# 6                Energy-efficient Street Light Design
# 7    Smart Street Light Poles with Integrated Sensors
# 8            Predictive Maintenance for Street Lights
# 9                  Connected Street Lighting Networks
# 10           Centralized Street Light Control Systems
# 11                    Dynamic Street Light Scheduling
# 12            Smart Street Lighting for Public Safety
# 13             Environmental Sensors on Street Lights
# 14  Wireless Communication for Street Light Coordi...
# 15         Automated Fault Detection in Street Lights
# 16            Real-time Energy Consumption Monitoring
# 17        Integration with Traffic Management Systems
# 18                     Intelligent Crosswalk Lighting
# 19                Adaptive Street Lighting for Events
# 20                        Street Light Data Analytics
# 21     Smart Street Lighting for Urban Beautification
# 22            Weather-responsive Street Light Control
# 23               Collaborative Street Lighting Design
# 24  Emergency Response Integration with Street Lights
# 25   Citizen Engagement Platforms for Street Lighting
# 26           Artistic and Interactive Street Lighting
# 27   Street Light Positioning for Enhanced Visibility
# 28         Integration with Smart City Infrastructure
# 29  Urban Planning with Smart Street Lighting Anal...
#
#                                    Urban Green Spaces  \
# 0                    Smart Park Design and Management
# 1                    Green Roofs and Vertical Gardens
# 2            Intelligent Irrigation Systems for Parks
# 3                     Urban Biodiversity Conservation
# 4          Sensor Networks for Green Space Monitoring
# 5                Smart Benches with Charging Stations
# 6               Interactive Outdoor Fitness Equipment
# 7        Virtual Green Spaces for Indoor Environments
# 8             Community Gardens with Smart Irrigation
# 9              Mobile Apps for Green Space Navigation
# 10                  Sustainable Landscaping Practices
# 11        Biodiversity Data Collection in Urban Areas
# 12                    Smart Lighting for Green Spaces
# 13                    Smart Waste Management in Parks
# 14                    Augmented Reality Nature Trails
# 15                       Urban Tree Canopy Monitoring
# 16     Citizen Engagement Platforms for Park Planning
# 17               Green Space Microclimates Monitoring
# 18                IoT-enabled Plant Health Monitoring
# 19                      Smart Urban Forestry Planning
# 20  Green Space Accessibility for Persons with Dis...
# 21                      Urban Agriculture Initiatives
# 22            Pollinator-friendly Green Space Designs
# 23          Social Inclusion Programs in Green Spaces
# 24                  Public Art Installations in Parks
# 25                Smart Water Features in Urban Parks
# 26      Integration of Green Spaces in Urban Planning
# 27          Environmental Education Programs in Parks
# 28              Urban Green Space Resilience Planning
# 29    Events and Activities Planning for Green Spaces
#
#                                 E-Government Services  \
# 0                 Digital Citizen Identity Management
# 1                           Online Government Portals
# 2                      Mobile Government Applications
# 3                  E-Government Service Accessibility
# 4                      Electronic Document Submission
# 5              Online Payment and Transaction Systems
# 6                              Smart Taxation Systems
# 7                                  E-Voting Platforms
# 8     Open Data Platforms for Government Transparency
# 9                    Digital Social Services Delivery
# 10               Digital Birth and Death Certificates
# 11                Electronic Permitting and Licensing
# 12      Real-time Government Alerts and Notifications
# 13         Government Chatbots for Citizen Assistance
# 14                        Online Public Consultations
# 15                 Smart Public Safety Reporting Apps
# 16                Cloud-based Government Data Storage
# 17                    E-Government Service Dashboards
# 18                 Government Social Media Engagement
# 19                         Digital Records Management
# 20  Smart City Command Centers for Government Coor...
# 21                 E-Health Services and Telemedicine
# 22                       Digital Educational Services
# 23                                  E-Justice Systems
# 24    E-Commerce Platforms for Government Procurement
# 25                         Virtual Town Hall Meetings
# 26      Blockchain for Secure Government Transactions
# 27  Geospatial Information Systems (GIS) for Gover...
# 28             Digital Cultural Heritage Preservation
# 29  Civic Engagement Platforms for Government-Comm...
#
#                                Air Quality Monitoring  \
# 0               Sensor Networks for Urban Air Quality
# 1                  IoT-enabled Air Quality Monitoring
# 2              Mobile Air Quality Monitoring Stations
# 3                         Real-time Pollution Mapping
# 4               Indoor Air Quality Monitoring Systems
# 5           Remote Sensing for Air Quality Assessment
# 6         Citizen-Engaged Air Quality Data Collection
# 7           Smart HVAC Systems for Indoor Air Quality
# 8                        Wearable Air Quality Sensors
# 9                Air Quality Alerts and Notifications
# 10  Integration with Traffic Management for Emissi...
# 11                    Atmospheric Dispersion Modeling
# 12                      Air Quality Prediction Models
# 13      Smart Urban Planning for Improved Air Quality
# 14        Public Awareness Campaigns on Air Pollution
# 15                Air Quality Analytics and Reporting
# 16  Sensor-equipped Public Transportation for Air ...
# 17    Air Quality Index (AQI) Visualization Platforms
# 18  Green Infrastructure for Air Pollution Mitigation
# 19  Smart Construction Site Management for Dust Co...
# 20            Vehicle Emission Monitoring and Control
# 21       Real-time Monitoring of Industrial Emissions
# 22  Integration with Health Systems for Air Qualit...
# 23  Urban Forestry Strategies for Air Quality Impr...
# 24  Smart Waste Management for Air Quality Preserv...
# 25  Machine Learning for Air Quality Pattern Recog...
# 26  Collaboration with Industries for Sustainable ...
# 27  Integration with Weather Forecasting for Air Q...
# 28                 Air Quality Data Sharing Platforms
# 29  Policy Initiatives for Air Quality Improvement...
#
#                               Smart Parking Solutions  \
# 0                IoT-enabled Parking Space Monitoring
# 1                Mobile Apps for Parking Availability
# 2                  Automated Parking Guidance Systems
# 3                      Sensor-equipped Parking Spaces
# 4                    Real-time Parking Occupancy Data
# 5                     Smart Parking Payment Solutions
# 6                  Dynamic Pricing for Parking Spaces
# 7                    Integration with Navigation Apps
# 8                       Parking Reservation Platforms
# 9                   Geofencing for Parking Management
# 10       License Plate Recognition for Parking Access
# 11                               Smart Parking Meters
# 12     Integration with Public Transportation Systems
# 13               Augmented Reality Parking Assistance
# 14               Connected Vehicles for Smart Parking
# 15                            Automated Valet Parking
# 16                    Parking Space Detection Cameras
# 17                      Cloud-based Parking Analytics
# 18  Integration with Electric Vehicle Charging Sta...
# 19                Smart Parking Enforcement Solutions
# 20          IoT-based Parking Infrastructure Planning
# 21                Real-time Traffic Flow Optimization
# 22                     Parking Space Utilization Data
# 23              Intelligent Parking Garage Management
# 24        Mobile Alerts for Expiring Parking Sessions
# 25           Collaboration with Ride-Sharing Services
# 26               Autonomous Vehicle Parking Solutions
# 27         Smart Parking for Bike and Scooter Sharing
# 28        Public Awareness Campaigns on Smart Parking
# 29  Integration with Urban Planning for Parking Op...
#
#                             Urban autonomous vehicles
# 0                  Self-Driving Public Transportation
# 1                    Autonomous Ride-Sharing Services
# 2                              Urban Autonomous Taxis
# 3                               Automated Bus Systems
# 4    Smart Traffic Management for Autonomous Vehicles
# 5           Vehicle-to-Everything (V2X) Communication
# 6                        Autonomous Delivery Vehicles
# 7            Last-Mile Autonomous Transport Solutions
# 8             Pedestrian Detection and Safety Systems
# 9     Integration with Public Transportation Networks
# 10    Smart Parking Solutions for Autonomous Vehicles
# 11                       Autonomous Freight Transport
# 12      Connected and Cooperative Autonomous Vehicles
# 13   Infrastructure Readiness for Autonomous Vehicles
# 14     Fleet Management for Urban Autonomous Vehicles
# 15         Autonomous Vehicle Charging Infrastructure
# 16  Regulations and Policies for Urban Autonomous ...
# 17   Real-time Traffic Flow Optimization for Autonomy
# 18       Urban Planning for Autonomous Vehicle Routes
# 19        Ride-Sharing Pools with Autonomous Vehicles
# 20       Autonomous Vehicle Data Security and Privacy
# 21             Multi-Modal Transportation Integration
# 22         Emergency Response for Autonomous Vehicles
# 23             User Experience in Autonomous Vehicles
# 24  Accessibility for Persons with Disabilities in...
# 25             Autonomous Vehicle Sensor Technologies
# 26  Environmental Impact of Autonomous Transportation
# 27  Collaboration with Smart Infrastructure for Au...
# 28          Autonomous Vehicle Simulation and Testing
# 29  Urban Resilience Planning with Autonomous Tran...

# %%
UM = subs['Urban Mobility'].values
ITS = subs['Intelligent Transportation Systems'].values
SG = subs['Smart Grids'].values
EM = subs['Energy Management'].values
SI = subs['Sustainable Infrastructure'].values
DG = subs['Digital Governance'].values
IiC = subs['IoT in Cities'].values
SB = subs['Smart Buildings'].values
WM = subs['Waste Management'].values
WaM = subs['Water Management'].values
CE = subs['Civic Engagement'].values
PS = subs['Public Safety'].values
EvM = subs['Environmental Monitoring'].values
UPA = subs['Urban Planning Analytics'].values
SSL = subs['Smart Street Lighting'].values
UGS = subs['Urban Green Spaces'].values
EGS = subs['E-Government Services'].values
AQM = subs['Air Quality Monitoring'].values
SPS = subs['Smart Parking Solutions'].values
UAV = subs['Urban autonomous vehicles'].values

# %%
def topic_allocation(sub_topic):
    if pd.isnull(sub_topic):
        return "NA"     
    if any(keyword in sub_topic for keyword in UM):
        return "Urban Mobility"
    elif any(keyword in sub_topic for keyword in ITS):
        return "Intelligent Transportation Systems"
    elif any(keyword in sub_topic for keyword in SG):
        return "Smart Grids"
    elif any(keyword in sub_topic for keyword in EM):
        return "Energy Management"
    elif any(keyword in sub_topic for keyword in SI):
        return "Sustainable Infrastructure"
    elif any(keyword in sub_topic for keyword in DG):
        return "Digital Governance"
    elif any(keyword in sub_topic for keyword in IiC):
        return "IoT in Cities"
    elif any(keyword in sub_topic for keyword in SB):
        return "Smart Buildings"
    elif any(keyword in sub_topic for keyword in WM):
        return "Waste Management"
    elif any(keyword in sub_topic for keyword in WaM):
        return "Water Management"
    elif any(keyword in sub_topic for keyword in CE):
        return "Civic Engagement"
    elif any(keyword in sub_topic for keyword in PS):
        return "Public Safety"
    elif any(keyword in sub_topic for keyword in EvM):
        return "Environmental Monitoring"
    elif any(keyword in sub_topic for keyword in UPA):
        return "Urban Planning Analytics"
    elif any(keyword in sub_topic for keyword in SSL):
        return "Smart Street Lighting"
    elif any(keyword in sub_topic for keyword in UGS):
        return "Urban Green Spaces"
    elif any(keyword in sub_topic for keyword in EGS):
        return "E-Government Services"
    elif any(keyword in sub_topic for keyword in AQM):
        return "Air Quality Monitoring"
    elif any(keyword in sub_topic for keyword in SPS):
        return "Smart Parking Solutions"
    elif any(keyword in sub_topic for keyword in UAV):
        return "Urban autonomous vehicles"
    else:
        return "Other"

# %%
smart_cities_df['Topic'] = smart_cities_df['Assigned Subtopic(Preprocessed)'].apply(topic_allocation)

# %%
smart_cities_df
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6578  Smart Cities   What is the projected trend of Indonesia's GDP...
# 6579  Smart Cities   How do landowners in India show preference het...
# 6580  Smart Cities   What is the purpose of SKI Jakarta Governor Re...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6577  The guidelines provided in the Proturan Enter ...
# 6578  According to O'Neill (2023), the Gross Domesti...
# 6579  According to Patel et al. (2020), landowners i...
# 6580  SKI Jakarta Governor Regulation Number 15 of 2...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6577                                         Management
# 6578                                           Analysis
# 6579                                           Analysis
# 6580                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6578  Smart urbanism, citizen-centric approaches and...
# 6579  Smart urbanism, citizen-centric approaches and...
# 6580  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  https://www.sciencedirect.com/science/article/...
# 6578  https://www.sciencedirect.com/science/article/...
# 6579  https://www.sciencedirect.com/science/article/...
# 6580  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6578  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6579  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6580  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
#                                                      QA  \
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6578  What is the projected trend of Indonesia's GDP...
# 6579  How do landowners in India show preference het...
# 6580  What is the purpose of SKI Jakarta Governor Re...
# 6581  How does the implementation strategy of transi...
#
#                                               QA_vector  \
# 0     [-0.012195684, 0.007873172, 0.006466941, 0.029...
# 1     [-0.019286802, 0.043021444, 0.012284794, -0.01...
# 2     [-0.02020133, 0.025334762, -0.002407805, -0.01...
# 3     [-0.051888514, 0.01082537, 0.017671604, -0.043...
# 4     [-0.0022440273, -0.008420247, 0.017052963, -0....
# ...                                                 ...
# 6577  [-0.014814504, 0.00951411, 0.023957323, -0.050...
# 6578  [-0.05541449, -0.0032068617, 0.071445845, -0.0...
# 6579  [-0.005819576, 0.008612114, 0.025815105, -0.02...
# 6580  [-0.02840907, -0.032079037, 0.06578252, -0.069...
# 6581  [-0.015211115, -0.0051177023, 0.06099411, -0.0...
#
#                      Assigned Subtopic  \
# 0     Grid Voltage Stability Solutions
# 1            Waste-to-Energy Solutions
# 2         Renewable Energy Integration
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 6577                               NaN
# 6578                               NaN
# 6579                               NaN
# 6580                               NaN
# 6581   Efficient Public Transportation
#
#                                                 QA_prep  \
# 0     operational strategies like bid price control ...
# 1     purpose powertohydrogen ph technology ph techn...
# 2     ph contribute integration variable renewable e...
# 3     surplus alone insufficient economical px syste...
# 4     best route ph terms displacing diesel heavy co...
# ...                                                 ...
# 6577  proturan enter agrarian dan tata huangbaden pe...
# 6578  projected trend indonesias gdp per capita acco...
# 6579  landowners india show preference heterogeneity...
# 6580  purpose ski jakarta governor regulation number...
# 6581  implementation strategy transitoriented develo...
#
#                                          QA_prep_vector  \
# 0     [-0.022449002, 0.018022422, 0.009411752, 0.048...
# 1     [-0.026798876, 0.043908987, 0.032166984, -0.00...
# 2     [-0.052468862, 0.017500032, 0.029401012, -0.01...
# 3     [-0.054230493, 0.025611764, 0.034356646, -0.02...
# 4     [-0.013488555, -0.013958169, 0.04522113, -0.02...
# ...                                                 ...
# 6577  [-0.014260622, -0.010944142, 0.051180813, -0.0...
# 6578  [-0.041214325, 0.00021408785, 0.07849644, -0.0...
# 6579  [-0.019319465, 0.017689066, 0.02719766, -0.023...
# 6580  [-0.016116215, -0.017762946, 0.05998256, -0.06...
# 6581  [-0.025303632, -0.0066138757, 0.05601606, -0.0...
#
#                         Assigned Subtopic(Preprocessed)  \
# 0                    Voltage and Reactive Power Control
# 1                         Grid-Connected Energy Storage
# 2                            Energy Storage Integration
# 3                           Energy Storage Optimization
# 4               Energy-efficient Transportation Systems
# ...                                                 ...
# 6577                        Public Transit Optimization
# 6578                                                NaN
# 6579                                                NaN
# 6580                                                NaN
# 6581  Integration with Urban Planning for Parking Op...
#
#                         Topic
# 0                 Smart Grids
# 1                 Smart Grids
# 2                 Smart Grids
# 3           Energy Management
# 4           Energy Management
# ...                       ...
# 6577           Urban Mobility
# 6578                       NA
# 6579                       NA
# 6580                       NA
# 6581  Smart Parking Solutions
#
# [6582 rows x 14 columns]

# %%
# Export unstripped dataset to CSV
smart_cities_df.to_csv('Smart Cities Unstripped Dataset---85percent.csv')

# %%
smart_cities_df_striped = smart_cities_df[smart_cities_df['Topic'] != 'NA']
smart_cities_df_striped
# Out:
#         Macrotopic                                            Question  \
# 0     Smart cities   How do operational strategies like bid price c...
# 1     Smart cities   What is the purpose of Power-to-Hydrogen (P2H)...
# 2     Smart cities   How does P2H contribute to the integration of ...
# 3     Smart cities   Why is surplus ARE alone insufficient for an e...
# 4     Smart cities   What is the best route for P2H in terms of dis...
# ...             ...                                                ...
# 6573  Smart Cities   Why is it important for participants to carefu...
# 6575  Smart Cities   According to Ali et al. (2021), what is the re...
# 6576  Smart Cities   What is the significance of transit oriented d...
# 6577  Smart Cities   How does the Proturan Enter Agrarian dan Tata ...
# 6581  Smart Cities   How does the implementation strategy of transi...
#
#                                                  Answer  \
# 0     Both bid price control and wind forecast contr...
# 1     P2H technology is used to store excess electri...
# 2     P2H technology helps to integrate ARE into the...
# 3     Surplus ARE alone is insufficient for an econo...
# 4     The best route for P2H is to displace diesel i...
# ...                                                 ...
# 6573  Participants should carefully consider each al...
# 6575  Ali et al. (2021) highlighted the dynamics of ...
# 6576  Transit Oriented Development (TOD) is signific...
# 6577  The guidelines provided in the Proturan Enter ...
# 6581  This strategy aims to promote efficient public...
#
#                                                   Label  \
# 0                                              Analysis
# 1                                      Science and Tech
# 2                                      Science and Tech
# 3     Why is it almost impossible for grid operators...
# 4                                              Strategy
# ...                                                 ...
# 6573                                           Strategy
# 6575                                   Science and tech
# 6576                                         Management
# 6577                                         Management
# 6581                                           Strategy
#
#                                           Source Title   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6573  Smart urbanism, citizen-centric approaches and...
# 6575  Smart urbanism, citizen-centric approaches and...
# 6576  Smart urbanism, citizen-centric approaches and...
# 6577  Smart urbanism, citizen-centric approaches and...
# 6581  Smart urbanism, citizen-centric approaches and...
#
#                                              Source Url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6573  https://www.sciencedirect.com/science/article/...
# 6575  https://www.sciencedirect.com/science/article/...
# 6576  https://www.sciencedirect.com/science/article/...
# 6577  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
#                                          Source Author   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6573  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6575  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6576  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6577  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
# 6581  I Mayan Koto Surya wan, Rachman Guyana, Ivan D...
#
#                                                      QA  \
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6573  Why is it important for participants to carefu...
# 6575  According to Ali et al. (2021), what is the re...
# 6576  What is the significance of transit oriented d...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6581  How does the implementation strategy of transi...
#
#                                               QA_vector  \
# 0     [-0.012195684, 0.007873172, 0.006466941, 0.029...
# 1     [-0.019286802, 0.043021444, 0.012284794, -0.01...
# 2     [-0.02020133, 0.025334762, -0.002407805, -0.01...
# 3     [-0.051888514, 0.01082537, 0.017671604, -0.043...
# 4     [-0.0022440273, -0.008420247, 0.017052963, -0....
# ...                                                 ...
# 6573  [0.0038841115, 0.03513701, 0.020665823, -0.060...
# 6575  [-0.0128415665, 0.002763815, 0.099401414, -0.0...
# 6576  [-0.0069669327, -0.0042390767, 0.053100187, -0...
# 6577  [-0.014814504, 0.00951411, 0.023957323, -0.050...
# 6581  [-0.015211115, -0.0051177023, 0.06099411, -0.0...
#
#                                       Assigned Subtopic  \
# 0                      Grid Voltage Stability Solutions
# 1                             Waste-to-Energy Solutions
# 2                          Renewable Energy Integration
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6573                                                NaN
# 6575  Policy Initiatives for Air Quality Improvement...
# 6576                        Public Transit Optimization
# 6577                                                NaN
# 6581                    Efficient Public Transportation
#
#                                                 QA_prep  \
# 0     operational strategies like bid price control ...
# 1     purpose powertohydrogen ph technology ph techn...
# 2     ph contribute integration variable renewable e...
# 3     surplus alone insufficient economical px syste...
# 4     best route ph terms displacing diesel heavy co...
# ...                                                 ...
# 6573  important participants carefully consider alte...
# 6575  according ali et al relationship transit orien...
# 6576  significance transit oriented development tod ...
# 6577  proturan enter agrarian dan tata huangbaden pe...
# 6581  implementation strategy transitoriented develo...
#
#                                          QA_prep_vector  \
# 0     [-0.022449002, 0.018022422, 0.009411752, 0.048...
# 1     [-0.026798876, 0.043908987, 0.032166984, -0.00...
# 2     [-0.052468862, 0.017500032, 0.029401012, -0.01...
# 3     [-0.054230493, 0.025611764, 0.034356646, -0.02...
# 4     [-0.013488555, -0.013958169, 0.04522113, -0.02...
# ...                                                 ...
# 6573  [-0.010255851, 0.022660147, 0.021899108, -0.05...
# 6575  [-0.015362982, 0.003872255, 0.101223275, -0.01...
# 6576  [-0.0009637197, -0.016547738, 0.07069088, -0.0...
# 6577  [-0.014260622, -0.010944142, 0.051180813, -0.0...
# 6581  [-0.025303632, -0.0066138757, 0.05601606, -0.0...
#
#                         Assigned Subtopic(Preprocessed)  \
# 0                    Voltage and Reactive Power Control
# 1                         Grid-Connected Energy Storage
# 2                            Energy Storage Integration
# 3                           Energy Storage Optimization
# 4               Energy-efficient Transportation Systems
# ...                                                 ...
# 6573                                 Urban Green Spaces
# 6575                Sustainable Transportation Networks
# 6576                        Public Transit Optimization
# 6577                        Public Transit Optimization
# 6581  Integration with Urban Planning for Parking Op...
#
#                            Topic
# 0                    Smart Grids
# 1                    Smart Grids
# 2                    Smart Grids
# 3              Energy Management
# 4              Energy Management
# ...                          ...
# 6573  Sustainable Infrastructure
# 6575  Sustainable Infrastructure
# 6576              Urban Mobility
# 6577              Urban Mobility
# 6581     Smart Parking Solutions
#
# [4592 rows x 14 columns]

# %%
smart_cities_df_striped = smart_cities_df_striped[['Question', 'Answer', 'Macrotopic ', 'Topic',
                                                   'Assigned Subtopic(Preprocessed)', 'Source Url']]
smart_cities_df_striped
# Out:
#                                                Question  \
# 0     How do operational strategies like bid price c...
# 1     What is the purpose of Power-to-Hydrogen (P2H)...
# 2     How does P2H contribute to the integration of ...
# 3     Why is surplus ARE alone insufficient for an e...
# 4     What is the best route for P2H in terms of dis...
# ...                                                 ...
# 6573  Why is it important for participants to carefu...
# 6575  According to Ali et al. (2021), what is the re...
# 6576  What is the significance of transit oriented d...
# 6577  How does the Proturan Enter Agrarian dan Tata ...
# 6581  How does the implementation strategy of transi...
#
#                                                  Answer    Macrotopic   \
# 0     Both bid price control and wind forecast contr...  Smart cities
# 1     P2H technology is used to store excess electri...  Smart cities
# 2     P2H technology helps to integrate ARE into the...  Smart cities
# 3     Surplus ARE alone is insufficient for an econo...  Smart cities
# 4     The best route for P2H is to displace diesel i...  Smart cities
# ...                                                 ...            ...
# 6573  Participants should carefully consider each al...  Smart Cities
# 6575  Ali et al. (2021) highlighted the dynamics of ...  Smart Cities
# 6576  Transit Oriented Development (TOD) is signific...  Smart Cities
# 6577  The guidelines provided in the Proturan Enter ...  Smart Cities
# 6581  This strategy aims to promote efficient public...  Smart Cities
#
#                            Topic  \
# 0                    Smart Grids
# 1                    Smart Grids
# 2                    Smart Grids
# 3              Energy Management
# 4              Energy Management
# ...                          ...
# 6573  Sustainable Infrastructure
# 6575  Sustainable Infrastructure
# 6576              Urban Mobility
# 6577              Urban Mobility
# 6581     Smart Parking Solutions
#
#                         Assigned Subtopic(Preprocessed)  \
# 0                    Voltage and Reactive Power Control
# 1                         Grid-Connected Energy Storage
# 2                            Energy Storage Integration
# 3                           Energy Storage Optimization
# 4               Energy-efficient Transportation Systems
# ...                                                 ...
# 6573                                 Urban Green Spaces
# 6575                Sustainable Transportation Networks
# 6576                        Public Transit Optimization
# 6577                        Public Transit Optimization
# 6581  Integration with Urban Planning for Parking Op...
#
#                                              Source Url
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6573  https://www.sciencedirect.com/science/article/...
# 6575  https://www.sciencedirect.com/science/article/...
# 6576  https://www.sciencedirect.com/science/article/...
# 6577  https://www.sciencedirect.com/science/article/...
# 6581  https://www.sciencedirect.com/science/article/...
#
# [4592 rows x 6 columns]

# %%
smart_cities_df_striped.rename(columns={'Assigned Subtopic(Preprocessed)': 'Subtopic'}, inplace=True)
# Out:
# C:\Users\RedHat\AppData\Local\Temp\ipykernel_22376\3990020112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smart_cities_df_striped.rename(columns={'Assigned Subtopic(Preprocessed)': 'Subtopic'}, inplace=True)

# %%
smart_cities_df_striped.to_csv('Smart Cities for SUPERCLEANED dataset 23-3-2024.csv')

# %%
smart_cities_df.to_csv('Unstriped Smart Cities for SUPERCLEANED dataset 23-3-2024.csv')

# %% [markdown]
# # CLEAN ENERGY

# %%
afc_energy_df = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\Supercleaned demo dataset ready for Topic mod 21 03.xlsx", 
                       sheet_name=2)
afc_energy_df
# Out:
#                        Macrotopic   \
# 0     Affordable and Clean Energy
# 1     Affordable and Clean Energy
# 2     Affordable and Clean Energy
# 3     Affordable and Clean Energy
# 4     Affordable and Clean Energy
# ...                            ...
# 1660  Affordable and Clean Energy
# 1661  Affordable and Clean Energy
# 1662  Affordable and Clean Energy
# 1663  Affordable and Clean Energy
# 1664  Affordable and Clean Energy
#
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LIES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                                  Answer            Label   \
# 0     The main advantage of LIES is that it is geogr...  Science and Tech
# 1     The efficiency of LIES can be improved by util...        Management
# 2     The Round Trip Efficiency (RTE) can be improve...        Management
# 3     The Solar-LAES-SE system with decoupled chargi...          Analysis
# 4     Implementing renewable energy-based industrial...          Strategy
# ...                                                 ...               ...
# 1660  Solar irradiance in Spain was 20% to 30% above...          Analysis
# 1661  The negative phase of the North Atlantic Oscil...          Analysis
# 1662  The model showed that wind energy reduced life...  Science and Tech
# 1663  Even with up to 70% wind energy on the grid, t...          Analysis
# 1664  It is almost impossible for grid operators to ...          Analysis
#
#       Source Title   Source Url  Source Author
# 0               NaN         NaN             NaN
# 1               NaN         NaN             NaN
# 2               NaN         NaN             NaN
# 3               NaN         NaN             NaN
# 4               NaN         NaN             NaN
# ...             ...         ...             ...
# 1660            NaN         NaN             NaN
# 1661            NaN         NaN             NaN
# 1662            NaN         NaN             NaN
# 1663            NaN         NaN             NaN
# 1664            NaN         NaN             NaN
#
# [1665 rows x 7 columns]

# %%
afc_energy_df['QA'] = afc_energy_df['Question'] + ' ' + afc_energy_df['Answer']
afc_energy_df
# Out:
#                        Macrotopic   \
# 0     Affordable and Clean Energy
# 1     Affordable and Clean Energy
# 2     Affordable and Clean Energy
# 3     Affordable and Clean Energy
# 4     Affordable and Clean Energy
# ...                            ...
# 1660  Affordable and Clean Energy
# 1661  Affordable and Clean Energy
# 1662  Affordable and Clean Energy
# 1663  Affordable and Clean Energy
# 1664  Affordable and Clean Energy
#
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LIES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                                  Answer            Label   \
# 0     The main advantage of LIES is that it is geogr...  Science and Tech
# 1     The efficiency of LIES can be improved by util...        Management
# 2     The Round Trip Efficiency (RTE) can be improve...        Management
# 3     The Solar-LAES-SE system with decoupled chargi...          Analysis
# 4     Implementing renewable energy-based industrial...          Strategy
# ...                                                 ...               ...
# 1660  Solar irradiance in Spain was 20% to 30% above...          Analysis
# 1661  The negative phase of the North Atlantic Oscil...          Analysis
# 1662  The model showed that wind energy reduced life...  Science and Tech
# 1663  Even with up to 70% wind energy on the grid, t...          Analysis
# 1664  It is almost impossible for grid operators to ...          Analysis
#
#       Source Title   Source Url  Source Author   \
# 0               NaN         NaN             NaN
# 1               NaN         NaN             NaN
# 2               NaN         NaN             NaN
# 3               NaN         NaN             NaN
# 4               NaN         NaN             NaN
# ...             ...         ...             ...
# 1660            NaN         NaN             NaN
# 1661            NaN         NaN             NaN
# 1662            NaN         NaN             NaN
# 1663            NaN         NaN             NaN
# 1664            NaN         NaN             NaN
#
#                                                      QA
# 0     What is the main advantage of liquid air energ...
# 1     How can the efficiency of LIES be improved? Th...
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
# [1665 rows x 8 columns]

# %%
sub_df1 = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\clean energy topic and subtopics (2).xlsx", 
                                 sheet_name='subtopic description 1-15')
sub_df2 = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\clean energy topic and subtopics (2).xlsx", 
                                 sheet_name='Subtopics description (15-30)')
afce_subtopic_df = pd.concat([sub_df1, sub_df2], axis=0).reset_index(drop=True)
afce_subtopic_df
# Out:
#                           Topic                                      Subtopic  \
# 0    Solar Photovoltaic Systems               Solar Photovoltaic Technologies
# 1    Solar Photovoltaic Systems                       Grid-Tied Solar Systems
# 2    Solar Photovoltaic Systems                        Off-Grid Solar Systems
# 3    Solar Photovoltaic Systems           Solar Panel Manufacturing Processes
# 4    Solar Photovoltaic Systems                   Solar Inverter Technologies
# ..                          ...                                           ...
# 551                         NaN  Carbon Offsets and Biodiversity Conservation
# 552                         NaN           Carbon Footprint Reduction Programs
# 553                         NaN   Carbon Offset Programs for Small Businesses
# 554                         NaN         Carbon Neutral Events and Conferences
# 555                         NaN     Innovation in Carbon Offset Methodologies
#
#                                            Description  \
# 0    Solar photovoltaic (PV) technologies encompass...
# 1    Grid-tied solar systems are photovoltaic insta...
# 2    Off-grid solar systems operate independently o...
# 3    Solar panel manufacturing processes involve th...
# 4    Solar inverter technologies convert direct cur...
# ..                                                 ...
# 551  Carbon Offsets and Biodiversity Conservation p...
# 552  Carbon Footprint Reduction Programs implement ...
# 553  Carbon Offset Programs for Small Businesses en...
# 554  Carbon Neutral Events and Conferences aim to m...
# 555  Innovation in Carbon Offset Methodologies expl...
#
#                                               Keywords
# 0                    Solar PV, Photovoltaic, Renewable
# 1                Grid-tied, Solar system, Net metering
# 2                        Off-grid, Stand-alone, Remote
# 3                Manufacturing, Production, Efficiency
# 4                     Inverter, Conversion, Efficiency
# ..                                                 ...
# 551            habitat restoration, ecosystem services
# 552  greenhouse gas emissions, environmental perfor...
# 553        small enterprises, corporate responsibility
# 554  sustainable event planning, eco-friendly pract...
# 555       emission reductions, carbon market standards
#
# [556 rows x 4 columns]

# %%
# text embedding for clean energy corpus
text_embed('QA', afc_energy_df, 'QA_vector')
# Out:
#                        Macrotopic   \
# 0     Affordable and Clean Energy
# 1     Affordable and Clean Energy
# 2     Affordable and Clean Energy
# 3     Affordable and Clean Energy
# 4     Affordable and Clean Energy
# ...                            ...
# 1660  Affordable and Clean Energy
# 1661  Affordable and Clean Energy
# 1662  Affordable and Clean Energy
# 1663  Affordable and Clean Energy
# 1664  Affordable and Clean Energy
#
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LIES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                                  Answer            Label   \
# 0     The main advantage of LIES is that it is geogr...  Science and Tech
# 1     The efficiency of LIES can be improved by util...        Management
# 2     The Round Trip Efficiency (RTE) can be improve...        Management
# 3     The Solar-LAES-SE system with decoupled chargi...          Analysis
# 4     Implementing renewable energy-based industrial...          Strategy
# ...                                                 ...               ...
# 1660  Solar irradiance in Spain was 20% to 30% above...          Analysis
# 1661  The negative phase of the North Atlantic Oscil...          Analysis
# 1662  The model showed that wind energy reduced life...  Science and Tech
# 1663  Even with up to 70% wind energy on the grid, t...          Analysis
# 1664  It is almost impossible for grid operators to ...          Analysis
#
#       Source Title   Source Url  Source Author   \
# 0               NaN         NaN             NaN
# 1               NaN         NaN             NaN
# 2               NaN         NaN             NaN
# 3               NaN         NaN             NaN
# 4               NaN         NaN             NaN
# ...             ...         ...             ...
# 1660            NaN         NaN             NaN
# 1661            NaN         NaN             NaN
# 1662            NaN         NaN             NaN
# 1663            NaN         NaN             NaN
# 1664            NaN         NaN             NaN
#
#                                                      QA  \
# 0     What is the main advantage of liquid air energ...
# 1     How can the efficiency of LIES be improved? Th...
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                               QA_vector
# 0     [-0.004522498, -0.037984867, 0.036875945, 0.04...
# 1     [-0.046298273, -0.0027031552, 0.05756366, 0.00...
# 2     [-0.055615943, -0.003967587, 0.057388723, 0.01...
# 3     [-0.06440674, 0.0287099, 0.071825825, 0.034501...
# 4     [-0.039428297, 0.0035552864, 0.008631619, -0.0...
# ...                                                 ...
# 1660  [-0.023560774, -0.0006682332, 0.030136807, 0.0...
# 1661  [-0.05348125, 0.013398707, 0.0406969, -0.02428...
# 1662  [-0.034322396, 0.03786056, 0.03920884, 0.00370...
# 1663  [-0.01959131, 0.008530454, -0.0013339912, -0.0...
# 1664  [-0.04202134, 0.017730273, -0.026147071, -0.00...
#
# [1665 rows x 9 columns]

# %%
# subtopic embedding for clean energy
text_embed('Description', afce_subtopic_df, 'Des_vector')
# Out:
#                           Topic                                      Subtopic  \
# 0    Solar Photovoltaic Systems               Solar Photovoltaic Technologies
# 1    Solar Photovoltaic Systems                       Grid-Tied Solar Systems
# 2    Solar Photovoltaic Systems                        Off-Grid Solar Systems
# 3    Solar Photovoltaic Systems           Solar Panel Manufacturing Processes
# 4    Solar Photovoltaic Systems                   Solar Inverter Technologies
# ..                          ...                                           ...
# 551                         NaN  Carbon Offsets and Biodiversity Conservation
# 552                         NaN           Carbon Footprint Reduction Programs
# 553                         NaN   Carbon Offset Programs for Small Businesses
# 554                         NaN         Carbon Neutral Events and Conferences
# 555                         NaN     Innovation in Carbon Offset Methodologies
#
#                                            Description  \
# 0    Solar photovoltaic (PV) technologies encompass...
# 1    Grid-tied solar systems are photovoltaic insta...
# 2    Off-grid solar systems operate independently o...
# 3    Solar panel manufacturing processes involve th...
# 4    Solar inverter technologies convert direct cur...
# ..                                                 ...
# 551  Carbon Offsets and Biodiversity Conservation p...
# 552  Carbon Footprint Reduction Programs implement ...
# 553  Carbon Offset Programs for Small Businesses en...
# 554  Carbon Neutral Events and Conferences aim to m...
# 555  Innovation in Carbon Offset Methodologies expl...
#
#                                               Keywords  \
# 0                    Solar PV, Photovoltaic, Renewable
# 1                Grid-tied, Solar system, Net metering
# 2                        Off-grid, Stand-alone, Remote
# 3                Manufacturing, Production, Efficiency
# 4                     Inverter, Conversion, Efficiency
# ..                                                 ...
# 551            habitat restoration, ecosystem services
# 552  greenhouse gas emissions, environmental perfor...
# 553        small enterprises, corporate responsibility
# 554  sustainable event planning, eco-friendly pract...
# 555       emission reductions, carbon market standards
#
#                                             Des_vector
# 0    [-0.039536417, 0.046666723, 0.041797113, -0.00...
# 1    [-0.04853681, 0.024900572, 0.015712507, -0.008...
# 2    [-0.01492235, 0.045314435, 0.022829114, -0.004...
# 3    [-0.042553786, 0.034881733, 0.046635456, -0.02...
# 4    [-0.03541326, 0.034002777, 0.024631288, 0.0234...
# ..                                                 ...
# 551  [-0.025664518, 0.013868737, 0.047231656, 6.798...
# 552  [-0.03491686, 0.030108815, 0.06351311, 0.00390...
# 553  [-0.024124589, 0.01781019, 0.04456468, -0.0321...
# 554  [-0.058755726, 0.030933961, 0.030578673, -0.01...
# 555  [-0.031737376, 0.040676046, 0.05378925, -0.000...
#
# [556 rows x 5 columns]

# %%
# Subtopic assignment for clean energy dataset
assign_subtopic(afc_energy_df, 'QA_vector', afce_subtopic_df, afce_subtopic_df['Des_vector'], 'Subtopic', 'Assigned Subtopic')

# %%
afc_energy_df['QA_prep'] = afc_energy_df['QA'].apply(preprocess_text)

# %%
afce_subtopic_df['Des_prep'] = afce_subtopic_df['Description'].apply(preprocess_text)

# %%
# text embedding for preprocessed clean energy corpus
text_embed('QA_prep', afc_energy_df, 'QA_prep_vector')
# Out:
#                        Macrotopic   \
# 0     Affordable and Clean Energy
# 1     Affordable and Clean Energy
# 2     Affordable and Clean Energy
# 3     Affordable and Clean Energy
# 4     Affordable and Clean Energy
# ...                            ...
# 1660  Affordable and Clean Energy
# 1661  Affordable and Clean Energy
# 1662  Affordable and Clean Energy
# 1663  Affordable and Clean Energy
# 1664  Affordable and Clean Energy
#
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LIES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                                  Answer            Label   \
# 0     The main advantage of LIES is that it is geogr...  Science and Tech
# 1     The efficiency of LIES can be improved by util...        Management
# 2     The Round Trip Efficiency (RTE) can be improve...        Management
# 3     The Solar-LAES-SE system with decoupled chargi...          Analysis
# 4     Implementing renewable energy-based industrial...          Strategy
# ...                                                 ...               ...
# 1660  Solar irradiance in Spain was 20% to 30% above...          Analysis
# 1661  The negative phase of the North Atlantic Oscil...          Analysis
# 1662  The model showed that wind energy reduced life...  Science and Tech
# 1663  Even with up to 70% wind energy on the grid, t...          Analysis
# 1664  It is almost impossible for grid operators to ...          Analysis
#
#       Source Title   Source Url  Source Author   \
# 0               NaN         NaN             NaN
# 1               NaN         NaN             NaN
# 2               NaN         NaN             NaN
# 3               NaN         NaN             NaN
# 4               NaN         NaN             NaN
# ...             ...         ...             ...
# 1660            NaN         NaN             NaN
# 1661            NaN         NaN             NaN
# 1662            NaN         NaN             NaN
# 1663            NaN         NaN             NaN
# 1664            NaN         NaN             NaN
#
#                                                      QA  \
# 0     What is the main advantage of liquid air energ...
# 1     How can the efficiency of LIES be improved? Th...
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                               QA_vector  \
# 0     [-0.004522498, -0.037984867, 0.036875945, 0.04...
# 1     [-0.046298273, -0.0027031552, 0.05756366, 0.00...
# 2     [-0.055615943, -0.003967587, 0.057388723, 0.01...
# 3     [-0.06440674, 0.0287099, 0.071825825, 0.034501...
# 4     [-0.039428297, 0.0035552864, 0.008631619, -0.0...
# ...                                                 ...
# 1660  [-0.023560774, -0.0006682332, 0.030136807, 0.0...
# 1661  [-0.05348125, 0.013398707, 0.0406969, -0.02428...
# 1662  [-0.034322396, 0.03786056, 0.03920884, 0.00370...
# 1663  [-0.01959131, 0.008530454, -0.0013339912, -0.0...
# 1664  [-0.04202134, 0.017730273, -0.026147071, -0.00...
#
#                                Assigned Subtopic  \
# 0           Compressed Air Energy Storage (CAES)
# 1                                            NaN
# 2              Geothermal Power Plant Efficiency
# 3                    Solar Inverter Technologies
# 4                   Industrial Energy Management
# ...                                          ...
# 1660                                         NaN
# 1661                                         NaN
# 1662  Social and Economic Benefits of Wind Farms
# 1663                   Small-Scale Wind Turbines
# 1664          Grid-Friendly Wind Farm Operations
#
#                                                 QA_prep  \
# 0     main advantage liquid air energy storage lies ...
# 1     efficiency lies improved efficiency lies impro...
# 2     round trip efficiency rte improved less lnglae...
# 3     solarlaesse system decoupled charging discharg...
# 4     implementing renewable energybased industrial ...
# ...                                                 ...
# 1660  solar irradiance spain compare rest europe apr...
# 1661  weather conditions europe responsible lowpress...
# 1662  based model constructed using data irish grid ...
# 1663  despite high share wind energy irish grid achi...
# 1664  almost impossible grid operators accept high w...
#
#                                          QA_prep_vector
# 0     [0.0001286425, -0.0215348, 0.03705814, 0.03461...
# 1     [-0.05188921, 0.008030583, 0.05519354, 0.01358...
# 2     [-0.054776583, -0.004049266, 0.050917335, 0.01...
# 3     [-0.059689205, 0.033795923, 0.055474304, 0.027...
# 4     [-0.04669596, 0.0006737985, 0.03521731, -0.023...
# ...                                                 ...
# 1660  [-0.03631249, 0.0058690365, 0.034752488, 0.027...
# 1661  [-0.07678591, -0.0010808985, 0.036194973, -0.0...
# 1662  [-0.044054758, 0.023186581, 0.034040935, -0.00...
# 1663  [-0.039006848, 0.020299856, 0.0010144438, 0.00...
# 1664  [-0.054294873, 0.032890983, -0.011106065, 0.00...
#
# [1665 rows x 12 columns]

# %%
# subtopic embedding for preprocessed clean energy description
text_embed('Des_prep', afce_subtopic_df, 'Des_prep_vector')
# Out:
#                           Topic                                      Subtopic  \
# 0    Solar Photovoltaic Systems               Solar Photovoltaic Technologies
# 1    Solar Photovoltaic Systems                       Grid-Tied Solar Systems
# 2    Solar Photovoltaic Systems                        Off-Grid Solar Systems
# 3    Solar Photovoltaic Systems           Solar Panel Manufacturing Processes
# 4    Solar Photovoltaic Systems                   Solar Inverter Technologies
# ..                          ...                                           ...
# 551                         NaN  Carbon Offsets and Biodiversity Conservation
# 552                         NaN           Carbon Footprint Reduction Programs
# 553                         NaN   Carbon Offset Programs for Small Businesses
# 554                         NaN         Carbon Neutral Events and Conferences
# 555                         NaN     Innovation in Carbon Offset Methodologies
#
#                                            Description  \
# 0    Solar photovoltaic (PV) technologies encompass...
# 1    Grid-tied solar systems are photovoltaic insta...
# 2    Off-grid solar systems operate independently o...
# 3    Solar panel manufacturing processes involve th...
# 4    Solar inverter technologies convert direct cur...
# ..                                                 ...
# 551  Carbon Offsets and Biodiversity Conservation p...
# 552  Carbon Footprint Reduction Programs implement ...
# 553  Carbon Offset Programs for Small Businesses en...
# 554  Carbon Neutral Events and Conferences aim to m...
# 555  Innovation in Carbon Offset Methodologies expl...
#
#                                               Keywords  \
# 0                    Solar PV, Photovoltaic, Renewable
# 1                Grid-tied, Solar system, Net metering
# 2                        Off-grid, Stand-alone, Remote
# 3                Manufacturing, Production, Efficiency
# 4                     Inverter, Conversion, Efficiency
# ..                                                 ...
# 551            habitat restoration, ecosystem services
# 552  greenhouse gas emissions, environmental perfor...
# 553        small enterprises, corporate responsibility
# 554  sustainable event planning, eco-friendly pract...
# 555       emission reductions, carbon market standards
#
#                                             Des_vector  \
# 0    [-0.039536417, 0.046666723, 0.041797113, -0.00...
# 1    [-0.04853681, 0.024900572, 0.015712507, -0.008...
# 2    [-0.01492235, 0.045314435, 0.022829114, -0.004...
# 3    [-0.042553786, 0.034881733, 0.046635456, -0.02...
# 4    [-0.03541326, 0.034002777, 0.024631288, 0.0234...
# ..                                                 ...
# 551  [-0.025664518, 0.013868737, 0.047231656, 6.798...
# 552  [-0.03491686, 0.030108815, 0.06351311, 0.00390...
# 553  [-0.024124589, 0.01781019, 0.04456468, -0.0321...
# 554  [-0.058755726, 0.030933961, 0.030578673, -0.01...
# 555  [-0.031737376, 0.040676046, 0.05378925, -0.000...
#
#                                               Des_prep  \
# 0    solar photovoltaic pv technologies encompass v...
# 1    gridtied solar systems photovoltaic installati...
# 2    offgrid solar systems operate independently el...
# 3    solar panel manufacturing processes involve fa...
# 4    solar inverter technologies convert direct cur...
# ..                                                 ...
# 551  carbon offsets biodiversity conservation proje...
# 552  carbon footprint reduction programs implement ...
# 553  carbon offset programs small businesses enable...
# 554  carbon neutral events conferences aim minimize...
# 555  innovation carbon offset methodologies explore...
#
#                                        Des_prep_vector
# 0    [-0.04240937, 0.022927899, 0.070242435, -0.019...
# 1    [-0.06875977, 0.017120644, 0.0038857667, -0.01...
# 2    [-0.010985108, 0.01931899, 0.030053258, -0.004...
# 3    [-0.043765012, 0.041055497, 0.054430105, -0.02...
# 4    [-0.050924208, 0.030663075, 0.028110225, 0.008...
# ..                                                 ...
# 551  [-0.021346644, 0.0083611095, 0.051733196, 0.00...
# 552  [-0.03552793, 0.027457634, 0.070954815, -0.005...
# 553  [-0.0234186, 0.018056037, 0.04026378, -0.02994...
# 554  [-0.051341422, 0.03127225, 0.0458548, -0.00431...
# 555  [-0.038984627, 0.043242123, 0.05137673, -0.001...
#
# [556 rows x 7 columns]

# %%
#Subtopic assignment for clean energy dataset
assign_subtopic(afc_energy_df, 'QA_prep_vector', afce_subtopic_df, afce_subtopic_df['Des_prep_vector'], 'Subtopic', 'Assigned Subtopic(Preprocessed)')

# %%
subs_cleanenergy = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\clean energy topic and subtopics (2).xlsx", 
                                 sheet_name=1)
subs_cleanenergy
# Out:
#                          Solar Photovoltaic Systems  \
# 0                   Solar Photovoltaic Technologies
# 1                            Grid-TiedSolar Systems
# 2                            Off-Grid Solar Systems
# 3               Solar Panel Manufacturing Processes
# 4                       Solar Inverter Technologies
# 5                      Photovoltaic Cell Efficiency
# 6                   Solar Battery Storage Solutions
# 7               Solar Energy Policy and Regulations
# 8                  Net Metering and Feed-in Tariffs
# 9     Solar Photovoltaic Integration in Smart Grids
# 10            Solar Photovoltaic Monitoring Systems
# 11            Advancements in Solar Panel Materials
# 12                      Community Solar Initiatives
# 13  Solar Photovoltaic for Residential Applications
# 14   Solar Photovoltaic for Commercial Applications
# 15   Solar Photovoltaic for Industrial Applications
# 16                Solar Photovoltaic in Agriculture
# 17    Economic Impact of Solar Photovoltaic Systems
# 18    Life Cycle Assessment of Solar Energy Systems
# 19                                              NaN
#
#                                   Wind Turbines  \
# 0                     Wind Turbine Technologies
# 1                            Onshore Wind Farms
# 2                           Offshore Wind Farms
# 3            Wind Turbine Design and Efficiency
# 4                       Wind Turbine Components
# 5                 Wind Turbine Blade Technology
# 6                        Wind Turbine Gearboxes
# 7                  Wind Turbine Control Systems
# 8                      Wind Turbine Maintenance
# 9       Wind Turbine Monitoring and Diagnostics
# 10             Wind Energy Storage Technologies
# 11  Wind Turbine Noise and Environmental Impact
# 12      Micro-Wind Turbines for Residential Use
# 13             Community Wind Power Initiatives
# 14                     Wind Resource Assessment
# 15           Wind Energy Policy and Regulations
# 16               Grid Integration of Wind Power
# 17           Advances in Wind Turbine Materials
# 18          Wind Turbines and Bird Conservation
# 19            Economic Viability of Wind Energy
#
#                            Hydropower Plants  \
# 0                     Hydropower Plant Types
# 1                    Run-of-River Hydropower
# 2                       Reservoir Hydropower
# 3                  Pumped Storage Hydropower
# 4                    Hydropower Plant Design
# 5                       Turbine Technologies
# 6                      Hydropower Efficiency
# 7         Environmental Impact of Hydropower
# 8      Fish-friendly Hydropower Technologies
# 9          Sediment Management in Hydropower
# 10           Hydropower Plant Rehabilitation
# 11                    Small-Scale Hydropower
# 12               Off-Grid Hydropower Systems
# 13            Grid Integration of Hydropower
# 14              Hydropower and Flood Control
# 15  Hydropower and Water Resource Management
# 16              Social Impacts of Hydropower
# 17         Hydropower Policy and Regulations
# 18         Advances in Hydropower Technology
# 19          Economic Viability of Hydropower
#
#                             Geothermal Energy  \
# 0             Geothermal Resource Exploration
# 1                     Geothermal Power Plants
# 2           Enhanced Geothermal Systems (EGS)
# 3             Direct Use of Geothermal Energy
# 4        Binary Cycle Geothermal Power Plants
# 5         Flash Steam Geothermal Power Plants
# 6                       Geothermal Heat Pumps
# 7            Geothermal Reservoir Engineering
# 8                  Geothermal Fluid Chemistry
# 9                    Geothermal Well Drilling
# 10          Geothermal Power Plant Efficiency
# 11            Geothermal Environmental Impact
# 12          Geothermal Energy and Earthquakes
# 13                Geothermal District Heating
# 14                 Geothermal Cooling Systems
# 15       Geothermal Power in Volcanic Regions
# 16   Geothermal Energy Policy and Regulations
# 17          Advances in Geothermal Technology
# 18  Geothermal Energy in Developing Countries
# 19    Economic Viability of Geothermal Energy
#
#                              Biomass Energy  \
# 0                        Biomass Feedstocks
# 1         Bioenergy Conversion Technologies
# 2                      Biomass Power Plants
# 3            Biogas Production from Biomass
# 4                 Biomass Pellet Production
# 5                       Anaerobic Digestion
# 6                      Biomass Gasification
# 7                        Biomass Combustion
# 8                Cofiring Biomass with Coal
# 9                  Biomass for Heat and CHP
# 10                  Biomass-to-Liquid (BTL)
# 11        Biochemical Conversion of Biomass
# 12           Sustainable Biomass Harvesting
# 13      Land Use and Biomass Sustainability
# 14  Biomass Energy and Carbon Sequestration
# 15    Biomass Energy Policy and Regulations
# 16           Advances in Biomass Technology
# 17      Biomass Energy in Rural Development
# 18     Economic Viability of Biomass Energy
# 19       Biomass Energy and Waste-to-Energy
#
#                             Tidal and Wave Energy  \
# 0                       Tidal Energy Technologies
# 1                         Tidal Stream Generators
# 2                        Tidal Range Technologies
# 3                                  Tidal Barrages
# 4                          Wave Energy Converters
# 5                                 Point Absorbers
# 6                       Oscillating Water Columns
# 7                                     Attenuators
# 8                             Overtopping Devices
# 9       Tidal and Wave Energy Resource Assessment
# 10      Grid Integration of Tidal and Wave Energy
# 11           Environmental Impact of Tidal Energy
# 12            Environmental Impact of Wave Energy
# 13                        Marine Spatial Planning
# 14              Tidal and Wave Energy Farm Design
# 15                  Tidal and Wave Energy Storage
# 16   Tidal and Wave Energy Policy and Regulations
# 17   Advances in Tidal and Wave Energy Technology
# 18    Economic Viability of Tidal and Wave Energy
# 19  Community Engagement in Tidal and Wave Energy
#
#                      Energy Storage Technologies  \
# 0          Battery Energy Storage Systems (BESS)
# 1                 Lithium-Ion Battery Technology
# 2                           Flow Battery Systems
# 3                           Pumped Hydro Storage
# 4           Compressed Air Energy Storage (CAES)
# 5                        Flywheel Energy Storage
# 6                         Thermal Energy Storage
# 7                     Molten Salt Energy Storage
# 8                                Supercapacitors
# 9          Advanced Materials for Energy Storage
# 10     Smart Grid and Energy Storage Integration
# 11           Grid-Scale Energy Storage Solutions
# 12            Distributed Energy Storage Systems
# 13              Vehicle-to-Grid (V2G) Technology
# 14      Energy Storage Management Systems (ESMS)
# 15         Energy Storage Policy and Regulations
# 16                      Microgrid Energy Storage
# 17       Advances in Energy Storage Technologies
# 18  Economic Viability of Energy Storage Systems
# 19        Environmental Impact of Energy Storage
#
#                               Smart Grid Technologies  \
# 0              Advanced Metering Infrastructure (AMI)
# 1               Smart Grid Communication Technologies
# 2                             Demand Response Systems
# 3                            Smart Grid Cybersecurity
# 4                         Grid Automation and Control
# 5            Distributed Energy Resources Integration
# 6                              Microgrid Technologies
# 7   Electric Vehicle (EV) Integration with Smart Grid
# 8          Energy Storage Integration with Smart Grid
# 9                        Smart Sensors and Monitoring
# 10                       Wide-Area Monitoring Systems
# 11                    Grid Resilience and Reliability
# 12                          Smart Grid Data Analytics
# 13                        Smart Grid Interoperability
# 14                Intelligent Substation Technologies
# 15                  Smart Grid Policy and Regulations
# 16                    Energy Management Systems (EMS)
# 17              Smart Homes and Buildings Integration
# 18                  Advanced Power Quality Monitoring
# 19      Economic Viability of Smart Grid Technologies
#
#                           Energy-Efficient Lighting  \
# 0                      Light Emitting Diodes (LEDs)
# 1                  Compact Fluorescent Lamps (CFLs)
# 2               Energy-Efficient Incandescent Bulbs
# 3                        Halogen Incandescent Lamps
# 4                     Lighting Controls and Sensors
# 5                            Smart Lighting Systems
# 6                               Daylight Harvesting
# 7                            Tunable White Lighting
# 8                            Human-Centric Lighting
# 9                 Energy Star and Labeling Programs
# 10         Light Pollution and Dark Sky Initiatives
# 11                 Energy-Efficient Street Lighting
# 12               Outdoor Area Lighting Technologies
# 13                  Lighting Retrofits and Upgrades
# 14   Energy-Efficient Lighting in Commercial Spaces
# 15  Energy-Efficient Lighting in Residential Spaces
# 16                          Task Lighting Solutions
# 17             Lighting for Energy-Efficient Cities
# 18   Life-Cycle Assessment of Lighting Technologies
# 19  Economic Viability of Energy-Efficient Lighting
#
#                Energy for sustainable Transportation  ...  \
# 0                            Electric Vehicles (EVs)  ...
# 1                    Hybrid Electric Vehicles (HEVs)  ...
# 2           Plug-In Hybrid Electric Vehicles (PHEVs)  ...
# 3                   Battery Electric Vehicles (BEVs)  ...
# 4                        Hydrogen Fuel Cell Vehicles  ...
# 5               Alternative Fuels for Transportation  ...
# 6                  Biofuels for Sustainable Mobility  ...
# 7                         Sustainable Urban Mobility  ...
# 8                    Charging Infrastructure for EVs  ...
# 9                  Vehicle-to-Grid (V2G) Integration  ...
# 10                 Autonomous and Connected Vehicles  ...
# 11    High-Speed Rail for Sustainable Transportation  ...
# 12                 Electrified Public Transportation  ...
# 13              Eco-Friendly Transportation Policies  ...
# 14             Green Logistics and Freight Transport  ...
# 15            Sustainable Aviation and Air Transport  ...
# 16    Cycling and Pedestrian-Friendly Infrastructure  ...
# 17               Sustainable Transportation Planning  ...
# 18     Life-Cycle Analysis of Transportation Systems  ...
# 19  Economic Viability of Sustainable Transportation  ...
#
#                                         Microgrids  \
# 0                Decentralized Energy Distribution
# 1                              Off-Grid Microgrids
# 2       Renewable Energy Integration in Microgrids
# 3          Energy Storage Solutions for Microgrids
# 4           Smart Grid Technologies for Microgrids
# 5         Microgrid Control and Management Systems
# 6         Resilience and Reliability in Microgrids
# 7               Community-Based Microgrid Projects
# 8                              Islanded Microgrids
# 9                        Remote Area Power Systems
# 10                             Grid-TiedMicrogrids
# 11                     Microgrid Sizing and Design
# 12           Combined Heat and Power in Microgrids
# 13                 Energy Management in Microgrids
# 14                         Microgrid Cybersecurity
# 15  Integration of Electric Vehicles in Microgrids
# 16       Financing Models for Microgrid Deployment
# 17            Policy and Regulatory Considerations
# 18                          Microgrid Case Studies
# 19   Technological Advances in Microgrid Solutions
#
#                      Energy Management Systems  \
# 0                      Demand Response Systems
# 1                       Smart Grid Integration
# 2               Home Energy Management Systems
# 3                 Industrial Energy Management
# 4                   Building Energy Management
# 5                  Microgrid Energy Management
# 6                Cloud-Based Energy Management
# 7                 Energy Efficiency Monitoring
# 8             Automated Energy Control Systems
# 9                         Peak Load Management
# 10                  Real-time Energy Analytics
# 11     Integration of Renewable Energy Sources
# 12                 Predictive Energy Analytics
# 13                   Energy Storage Management
# 14                      Demand-Side Management
# 15              Grid Optimization Technologies
# 16    Intelligent Energy Management Algorithms
# 17  Cybersecurity in Energy Management Systems
# 18   User Interface and User Experience in EMS
# 19        Performance Monitoring and Reporting
#
#                           Clean Energy Integration  \
# 0             Grid Integration of Renewable Energy
# 1                  Hybrid Renewable Energy Systems
# 2                       Energy Storage Integration
# 3      Integration of Distributed Energy Resources
# 4                     Smart Grids and Clean Energy
# 5                            Microgrid Integration
# 6                 Demand Response and Clean Energy
# 7                             Virtual Power Plants
# 8                 Integration of Electric Vehicles
# 9                        Power-to-Gas Technologies
# 10       Integrating Bioenergy into the Power Grid
# 11              Clean Energy and Energy Efficiency
# 12           Cross-Border Clean Energy Integration
# 13              Integration of Offshore Wind Farms
# 14              Advanced Energy Management Systems
# 15                    Renewable Energy Forecasting
# 16           Coordinated Planning for Clean Energy
# 17   Electrification of Heating and Transportation
# 18  Digital Platforms for Clean Energy Integration
# 19   Climate-Resilient Clean Energy Infrastructure
#
#                             Community Solar Projects  \
# 0                             Community Solar Models
# 1                              Shared Solar Programs
# 2             Solar Gardens and Collective Ownership
# 3             Low-Income Community Solar Initiatives
# 4           Virtual Net Metering for Community Solar
# 5             Community Solar Policy and Regulations
# 6                   Community Solar Financing Models
# 7              Community Solar in Urban Environments
# 8                     Community Solar in Rural Areas
# 9               Benefits of Community Solar Projects
# 10        Challenges in Implementing Community Solar
# 11         Community Engagement in Solar Initiatives
# 12    Innovative Business Models for Community Solar
# 13                 Community Solar and Energy Equity
# 14  Integration of Energy Storage in Community Solar
# 15            Microgrids in Community Solar Projects
# 16            Community Solar Education and Outreach
# 17                        Scaling Up Community Solar
# 18         Technological Advances in Community Solar
# 19  Collaborations between Communities and Utilities
#
#                       Urban planning clean energy   \
# 0                         Sustainable Urban Design
# 1                  Energy-Efficient Building Codes
# 2   Integration of Renewable Energy in Urban Areas
# 3                    Green Building Certifications
# 4                    Smart Cities and Clean Energy
# 5          Electrification of Urban Transportation
# 6           Green Infrastructure in Urban Planning
# 7                      Net-Zero Energy Communities
# 8                     Urban Heat Island Mitigation
# 9           District Energy Systems in Urban Areas
# 10               Urban Rooftop Solar Installations
# 11                Energy-Efficient Street Lighting
# 12     Waste-to-Energy Technologies in Urban Areas
# 13                   Sustainable Land Use Planning
# 14                  Public Transit Electrification
# 15  Incentives for Clean Energy Adoption in Cities
# 16    Circular Economy Practices in Urban Planning
# 17                     Urban Microgrid Development
# 18                       Green Roof Implementation
# 19                Climate-Resilient Urban Planning
#
#                                   Climate Resilience  \
# 0      Resilience Planning for Energy Infrastructure
# 1                   Climate-Resilient Energy Systems
# 2        Disaster Preparedness for Energy Facilities
# 3                    Microgrid Resilience Strategies
# 4              Renewable Energy in Disaster Recovery
# 5                Resilient Grid Design and Operation
# 6                  Coastal Infrastructure Resilience
# 7                   Climate-Resilient Building Codes
# 8              Heatwave Resilience in Energy Systems
# 9              Flood-Resilient Energy Infrastructure
# 10                Drought-Resilient Energy Solutions
# 11         Resilience of Energy Storage Technologies
# 12           Extreme Weather Preparedness for Energy
# 13        Cybersecurity for Resilient Energy Systems
# 14      Social Equity in Climate Resilience Planning
# 15          Climate-Resilient Transportation Systems
# 16       Early Warning Systems for Energy Facilities
# 17                   Community Resilience Strategies
# 18                  Climate-Resilient Urban Planning
# 19  Renewable Energy for Remote and Vulnerable Areas
#
#                                     Wind Farms  \
# 0                Onshore Wind Farm Development
# 1                  Offshore Wind Farm Projects
# 2             Wind Turbine Technology Advances
# 3                Wind Farm Siting and Planning
# 4                     Wind Resource Assessment
# 5                   Wind Farm Grid Integration
# 6                      Community Wind Projects
# 7                  Hybrid Wind and Solar Farms
# 8          Repowering and Upgrading Wind Farms
# 9           Advances in Wind Turbine Materials
# 10                         Floating Wind Farms
# 11         Wind Farm Operation and Maintenance
# 12            Impact of Wind Farms on Wildlife
# 13            Wind Farm Micrositing Strategies
# 14          Grid-Friendly Wind Farm Operations
# 15               Wind Energy Storage Solutions
# 16  Financing Models for Wind Farm Development
# 17                  Wind Farm Asset Management
# 18  Social and Economic Benefits of Wind Farms
# 19    Technological Innovations in Wind Energy
#
#                               Clean Energy skills  \
# 0          Renewable Energy Technologies Training
# 1        Energy Efficiency Certification Programs
# 2         Grid Management and Smart Grid Training
# 3              Sustainable Building Design Skills
# 4                  Energy Auditing and Management
# 5        Electric Vehicle Infrastructure Training
# 6                Energy Storage System Operations
# 7                    Hydrogen Technology Training
# 8          Solar Photovoltaic Installation Skills
# 9      Wind Turbine Maintenance and Repair Skills
# 10       Environmental Impact Assessment Training
# 11       Climate Adaptation and Resilience Skills
# 12         Cybersecurity for Clean Energy Systems
# 13     Energy Policy and Regulation Understanding
# 14     Geographic Information System (GIS) Skills
# 15           Circular Economy Practices Education
# 16    Climate Science and Climate Modeling Skills
# 17           Data Analytics for Energy Efficiency
# 18  Community Engagement and Communication Skills
# 19             Project Management in Clean Energy
#
#                        Renewable Energy Certification  \
# 0         Renewable Energy Certificate (REC) Programs
# 1                           Green Power Certification
# 2                         Carbon Offset Certification
# 3       Sustainability Standards for Renewable Energy
# 4                  Renewable Energy Labeling Programs
# 5           Third-Party Verification for Clean Energy
# 6            Environmental Product Declarations (EPD)
# 7                  ISO Standards for Renewable Energy
# 8                 Renewable Portfolio Standards (RPS)
# 9   Leadership in Energy and Environmental Design ...
# 10        Green Building Certification and Renewables
# 11  International Certification Standards for Rene...
# 12     Certification for Community Renewable Projects
# 13        Renewable Energy Supply Chain Certification
# 14                         Clean Energy Credit Rating
# 15           Certification for Offshore Wind Projects
# 16   Energy Star Certification for Renewable Products
# 17          Fair Trade Certification for Clean Energy
# 18  Social and Environmental Impact Certification ...
# 19  Certification for Renewable Energy Training Pr...
#
#                              Carbon Offset Programs
# 0                  Voluntary Carbon Offset Programs
# 1                  Compliance Carbon Offset Markets
# 2             Carbon Neutral Certification Programs
# 3                   Carbon Credit Trading Platforms
# 4   Renewable Energy Certificates (RECs) as Offsets
# 5          Afforestation and Reforestation Projects
# 6       Methane Capture and Utilization for Offsets
# 7       Blue Carbon Offsetting (Coastal Ecosystems)
# 8    Carbon Offset Projects in Developing Countries
# 9      Carbon Capture and Storage (CCS) for Offsets
# 10           Aviation and Carbon Offset Initiatives
# 11          Blockchain Technology in Carbon Markets
# 12           Community-Based Carbon Offset Projects
# 13        Carbon Offsets in Sustainable Agriculture
# 14                 Ocean-Based Carbon Sequestration
# 15     Carbon Offsets and Biodiversity Conservation
# 16              Carbon Footprint Reduction Programs
# 17      Carbon Offset Programs for Small Businesses
# 18            Carbon Neutral Events and Conferences
# 19        Innovation in Carbon Offset Methodologies
#
# [20 rows x 30 columns]

# %%
SPS = subs_cleanenergy['Solar Photovoltaic Systems']
SPS.dropna(inplace=True)

# %%
subs_cleanenergy.columns
# Out:
# Index(['Solar Photovoltaic Systems', 'Wind Turbines', 'Hydropower Plants',
#        'Geothermal Energy', 'Biomass Energy', 'Tidal and Wave Energy',
#        'Energy Storage Technologies', 'Smart Grid Technologies',
#        'Energy-Efficient Lighting', 'Energy for sustainable Transportation',
#        'Energy Electric Vehicles', 'Green Buildings',
#        'Energy-efficient Appliances', 'Carbon Capture and Storage',
#        'Green Hydrogen Production', 'Sustainable Agriculture Energy',
#        'Circular Economy Energy', 'Eco-Friendly Construction Materials',
#        'Ocean Thermal Energy ', 'Distributed Energy Resources', 'Microgrids',
#        'Energy Management Systems', 'Clean Energy Integration',
#        'Community Solar Projects', 'Urban planning clean energy ',
#        'Climate Resilience', ' Wind Farms', 'Clean Energy skills',
#        'Renewable Energy Certification', 'Carbon Offset Programs'],
#       dtype='object')

# %%
SPS = SPS.values
WT = subs_cleanenergy['Wind Turbines'].values
HP = subs_cleanenergy['Hydropower Plants'].values
GE = subs_cleanenergy['Geothermal Energy'].values
BE = subs_cleanenergy['Biomass Energy'].values
TWE = subs_cleanenergy['Tidal and Wave Energy'].values
EST = subs_cleanenergy['Energy Storage Technologies'].values
SGT = subs_cleanenergy['Smart Grid Technologies'].values
EEL = subs_cleanenergy['Energy-Efficient Lighting'].values
EnST = subs_cleanenergy['Energy for sustainable Transportation'].values
EEV = subs_cleanenergy['Energy Electric Vehicles'].values
GB = subs_cleanenergy['Green Buildings'].values
EEA = subs_cleanenergy['Energy-efficient Appliances'].values
CCS = subs_cleanenergy['Carbon Capture and Storage'].values
GHP = subs_cleanenergy['Green Hydrogen Production'].values
SAE = subs_cleanenergy['Sustainable Agriculture Energy'].values
CEE = subs_cleanenergy['Circular Economy Energy'].values
EFC = subs_cleanenergy['Eco-Friendly Construction Materials'].values
OTE = subs_cleanenergy['Ocean Thermal Energy '].values
DER = subs_cleanenergy['Distributed Energy Resources'].values
MGD = subs_cleanenergy['Microgrids'].values
EMS = subs_cleanenergy['Energy Management Systems'].values
CEI = subs_cleanenergy['Clean Energy Integration'].values
CSP = subs_cleanenergy['Community Solar Projects'].values
UPCE = subs_cleanenergy['Urban planning clean energy '].values
CR = subs_cleanenergy['Climate Resilience'].values
WF = subs_cleanenergy[' Wind Farms'].values
CES = subs_cleanenergy['Clean Energy skills'].values
REC = subs_cleanenergy['Renewable Energy Certification'].values
COP = subs_cleanenergy['Carbon Offset Programs'].values

# %%
missing_values = ['nan']
SPS_cleaned = SPS[~np.isin(SPS, missing_values)]

# %%
SPS_cleaned
# Out:
# array(['Solar Photovoltaic Technologies', 'Grid-TiedSolar Systems',
#        'Off-Grid Solar Systems', 'Solar Panel Manufacturing Processes',
#        'Solar Inverter Technologies', 'Photovoltaic Cell Efficiency',
#        'Solar Battery Storage Solutions',
#        'Solar Energy Policy and Regulations',
#        'Net Metering and Feed-in Tariffs',
#        'Solar Photovoltaic Integration in Smart Grids',
#        'Solar Photovoltaic Monitoring Systems',
#        'Advancements in Solar Panel Materials',
#        'Community Solar Initiatives',
#        'Solar Photovoltaic for Residential Applications',
#        'Solar Photovoltaic for Commercial Applications',
#        'Solar Photovoltaic for Industrial Applications',
#        'Solar Photovoltaic in Agriculture',
#        'Economic Impact of Solar Photovoltaic Systems',
#        'Life Cycle Assessment of Solar Energy Systems'], dtype=object)

# %%
def topic_allocation_clngy(sub_topic):
    if pd.isnull(sub_topic):
        return "NA"
    if any(keyword in sub_topic for keyword in SPS):
        return "Solar Photovoltaic Systems"
    elif any(keyword in sub_topic for keyword in WT):
        return "Wind Turbines"
    elif any(keyword in sub_topic for keyword in HP):
        return "Hydropower Plants"
    elif any(keyword in sub_topic for keyword in GE):
        return "Geothermal Energy"
    elif any(keyword in sub_topic for keyword in BE):
        return "Biomass Energy"
    elif any(keyword in sub_topic for keyword in TWE):
        return "Tidal and Wave Energy"
    elif any(keyword in sub_topic for keyword in EST):
        return "Energy Storage Technologies"
    elif any(keyword in sub_topic for keyword in SGT):
        return "Smart Grid Technologies"
    elif any(keyword in sub_topic for keyword in EEL):
        return "Energy-Efficient Lighting"
    elif any(keyword in sub_topic for keyword in EnST):
        return "Energy for sustainable Transportation"
    elif any(keyword in sub_topic for keyword in EEV):
        return "Energy Electric Vehicles"
    elif any(keyword in sub_topic for keyword in GB):
        return "Green Buildings"
    elif any(keyword in sub_topic for keyword in EEA):
        return "Energy-efficient Appliances"
    elif any(keyword in sub_topic for keyword in CCS):
        return "Carbon Capture and Storage"
    elif any(keyword in sub_topic for keyword in GHP):
        return "Green Hydrogen Production"
    elif any(keyword in sub_topic for keyword in SAE):
        return "Sustainable Agriculture Energy"
    elif any(keyword in sub_topic for keyword in CEE):
        return "Circular Economy Energy"
    elif any(keyword in sub_topic for keyword in EFC):
        return "Eco-Friendly Construction Materials"
    elif any(keyword in sub_topic for keyword in OTE):
        return "Ocean Thermal Energy"
    elif any(keyword in sub_topic for keyword in DER):
        return "Distributed Energy Resources"
    elif any(keyword in sub_topic for keyword in MGD):
        return "Microgrids"
    elif any(keyword in sub_topic for keyword in EMS):
        return "Energy Management Systems"
    elif any(keyword in sub_topic for keyword in CEI):
        return "Clean Energy Integration"
    elif any(keyword in sub_topic for keyword in CSP):
        return "Community Solar Projects"
    elif any(keyword in sub_topic for keyword in UPCE):
        return "Urban planning clean energy"
    elif any(keyword in sub_topic for keyword in CR):
        return "Climate Resilience"
    elif any(keyword in sub_topic for keyword in WF):
        return "Wind Farms"
    elif any(keyword in sub_topic for keyword in CES):
        return "Clean Energy skills"
    elif any(keyword in sub_topic for keyword in REC):
        return "Renewable Energy Certification"
    elif any(keyword in sub_topic for keyword in COP):
        return "Carbon Offset Programs"
    else:
        return "Other"

# %%
afc_energy_df['Topic'] = afc_energy_df['Assigned Subtopic(Preprocessed)'].apply(topic_allocation_clngy)

# %%
afc_energy_df
# Out:
#                        Macrotopic   \
# 0     Affordable and Clean Energy
# 1     Affordable and Clean Energy
# 2     Affordable and Clean Energy
# 3     Affordable and Clean Energy
# 4     Affordable and Clean Energy
# ...                            ...
# 1660  Affordable and Clean Energy
# 1661  Affordable and Clean Energy
# 1662  Affordable and Clean Energy
# 1663  Affordable and Clean Energy
# 1664  Affordable and Clean Energy
#
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LIES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                                  Answer            Label   \
# 0     The main advantage of LIES is that it is geogr...  Science and Tech
# 1     The efficiency of LIES can be improved by util...        Management
# 2     The Round Trip Efficiency (RTE) can be improve...        Management
# 3     The Solar-LAES-SE system with decoupled chargi...          Analysis
# 4     Implementing renewable energy-based industrial...          Strategy
# ...                                                 ...               ...
# 1660  Solar irradiance in Spain was 20% to 30% above...          Analysis
# 1661  The negative phase of the North Atlantic Oscil...          Analysis
# 1662  The model showed that wind energy reduced life...  Science and Tech
# 1663  Even with up to 70% wind energy on the grid, t...          Analysis
# 1664  It is almost impossible for grid operators to ...          Analysis
#
#       Source Title   Source Url  Source Author   \
# 0               NaN         NaN             NaN
# 1               NaN         NaN             NaN
# 2               NaN         NaN             NaN
# 3               NaN         NaN             NaN
# 4               NaN         NaN             NaN
# ...             ...         ...             ...
# 1660            NaN         NaN             NaN
# 1661            NaN         NaN             NaN
# 1662            NaN         NaN             NaN
# 1663            NaN         NaN             NaN
# 1664            NaN         NaN             NaN
#
#                                                      QA  \
# 0     What is the main advantage of liquid air energ...
# 1     How can the efficiency of LIES be improved? Th...
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1660  How did solar irradiance in Spain compare to t...
# 1661  What weather conditions in Europe were respons...
# 1662  Based on the model constructed using data from...
# 1663  Despite the high share of wind energy on the I...
# 1664  Why is it almost impossible for grid operators...
#
#                                               QA_vector  \
# 0     [-0.004522498, -0.037984867, 0.036875945, 0.04...
# 1     [-0.046298273, -0.0027031552, 0.05756366, 0.00...
# 2     [-0.055615943, -0.003967587, 0.057388723, 0.01...
# 3     [-0.06440674, 0.0287099, 0.071825825, 0.034501...
# 4     [-0.039428297, 0.0035552864, 0.008631619, -0.0...
# ...                                                 ...
# 1660  [-0.023560774, -0.0006682332, 0.030136807, 0.0...
# 1661  [-0.05348125, 0.013398707, 0.0406969, -0.02428...
# 1662  [-0.034322396, 0.03786056, 0.03920884, 0.00370...
# 1663  [-0.01959131, 0.008530454, -0.0013339912, -0.0...
# 1664  [-0.04202134, 0.017730273, -0.026147071, -0.00...
#
#                                Assigned Subtopic  \
# 0           Compressed Air Energy Storage (CAES)
# 1                                            NaN
# 2              Geothermal Power Plant Efficiency
# 3                    Solar Inverter Technologies
# 4                   Industrial Energy Management
# ...                                          ...
# 1660                                         NaN
# 1661                                         NaN
# 1662  Social and Economic Benefits of Wind Farms
# 1663                   Small-Scale Wind Turbines
# 1664          Grid-Friendly Wind Farm Operations
#
#                                                 QA_prep  \
# 0     main advantage liquid air energy storage lies ...
# 1     efficiency lies improved efficiency lies impro...
# 2     round trip efficiency rte improved less lnglae...
# 3     solarlaesse system decoupled charging discharg...
# 4     implementing renewable energybased industrial ...
# ...                                                 ...
# 1660  solar irradiance spain compare rest europe apr...
# 1661  weather conditions europe responsible lowpress...
# 1662  based model constructed using data irish grid ...
# 1663  despite high share wind energy irish grid achi...
# 1664  almost impossible grid operators accept high w...
#
#                                          QA_prep_vector  \
# 0     [0.0001286425, -0.0215348, 0.03705814, 0.03461...
# 1     [-0.05188921, 0.008030583, 0.05519354, 0.01358...
# 2     [-0.054776583, -0.004049266, 0.050917335, 0.01...
# 3     [-0.059689205, 0.033795923, 0.055474304, 0.027...
# 4     [-0.04669596, 0.0006737985, 0.03521731, -0.023...
# ...                                                 ...
# 1660  [-0.03631249, 0.0058690365, 0.034752488, 0.027...
# 1661  [-0.07678591, -0.0010808985, 0.036194973, -0.0...
# 1662  [-0.044054758, 0.023186581, 0.034040935, -0.00...
# 1663  [-0.039006848, 0.020299856, 0.0010144438, 0.00...
# 1664  [-0.054294873, 0.032890983, -0.011106065, 0.00...
#
#                      Assigned Subtopic(Preprocessed)  \
# 0                          Pumped Storage Hydropower
# 1                  Geothermal Power Plant Efficiency
# 2                  Geothermal Power Plant Efficiency
# 3                         Molten Salt Energy Storage
# 4     Solar Photovoltaic for Industrial Applications
# ...                                              ...
# 1660                                             NaN
# 1661                                             NaN
# 1662         Lifecycle Analysis of Electric Vehicles
# 1663              Integration of Offshore Wind Farms
# 1664              Grid-Friendly Wind Farm Operations
#
#                             Topic
# 0               Hydropower Plants
# 1               Geothermal Energy
# 2               Geothermal Energy
# 3     Energy Storage Technologies
# 4      Solar Photovoltaic Systems
# ...                           ...
# 1660                           NA
# 1661                           NA
# 1662     Energy Electric Vehicles
# 1663                Wind Turbines
# 1664                   Wind Farms
#
# [1665 rows x 14 columns]

# %%
afc_energy_df_striped = afc_energy_df[afc_energy_df['Topic'] != 'NA']

# %%
afc_energy_df_striped = afc_energy_df_striped[['Question', 'Answer', 'Macrotopic ', 'Topic',
                                                   'Assigned Subtopic(Preprocessed)', 'Source Url']]

# %%
afc_energy_df_striped.rename(columns={'Assigned Subtopic(Preprocessed)': 'Subtopic'}, inplace=True)
afc_energy_df_striped = afc_energy_df_striped.reset_index(drop=True)
# Out:
# C:\Users\RedHat\AppData\Local\Temp\ipykernel_29144\153472722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afc_energy_df_striped.rename(columns={'Assigned Subtopic(Preprocessed)': 'Subtopic'}, inplace=True)

# %%
afc_energy_df_striped
# Out:
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LIES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1257  What is the opinion of energy experts regardin...
# 1258  What are some concerns raised by energy expert...
# 1259  Based on the model constructed using data from...
# 1260  Despite the high share of wind energy on the I...
# 1261  Why is it almost impossible for grid operators...
#
#                                                  Answer  \
# 0     The main advantage of LIES is that it is geogr...
# 1     The efficiency of LIES can be improved by util...
# 2     The Round Trip Efficiency (RTE) can be improve...
# 3     The Solar-LAES-SE system with decoupled chargi...
# 4     Implementing renewable energy-based industrial...
# ...                                                 ...
# 1257  Energy experts strongly criticize the plans to...
# 1258  Energy experts have raised concerns about the ...
# 1259  The model showed that wind energy reduced life...
# 1260  Even with up to 70% wind energy on the grid, t...
# 1261  It is almost impossible for grid operators to ...
#
#                        Macrotopic                         Topic  \
# 0     Affordable and Clean Energy             Hydropower Plants
# 1     Affordable and Clean Energy             Geothermal Energy
# 2     Affordable and Clean Energy             Geothermal Energy
# 3     Affordable and Clean Energy   Energy Storage Technologies
# 4     Affordable and Clean Energy    Solar Photovoltaic Systems
# ...                            ...                          ...
# 1257  Affordable and Clean Energy    Solar Photovoltaic Systems
# 1258  Affordable and Clean Energy                 Wind Turbines
# 1259  Affordable and Clean Energy      Energy Electric Vehicles
# 1260  Affordable and Clean Energy                 Wind Turbines
# 1261  Affordable and Clean Energy                    Wind Farms
#
#                                             Subtopic  Source Url
# 0                          Pumped Storage Hydropower         NaN
# 1                  Geothermal Power Plant Efficiency         NaN
# 2                  Geothermal Power Plant Efficiency         NaN
# 3                         Molten Salt Energy Storage         NaN
# 4     Solar Photovoltaic for Industrial Applications         NaN
# ...                                              ...         ...
# 1257               Solar Photovoltaic in Agriculture         NaN
# 1258              Wind Energy Policy and Regulations         NaN
# 1259         Lifecycle Analysis of Electric Vehicles         NaN
# 1260              Integration of Offshore Wind Farms         NaN
# 1261              Grid-Friendly Wind Farm Operations         NaN
#
# [1262 rows x 6 columns]

# %%
afc_energy_df_striped.to_csv('Clean Energy for SUPERCLEANED dataset 23-3-2024.csv')

# %%
afc_energy_df.to_csv('Unstriped Clean Energy for SUPERCLEANED dataset 23-3-2024.csv')

# %% [markdown]
# # CLIMATE ACTION

# %%
climate_action_df = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\Supercleaned demo dataset ready for Topic mod 21 03.xlsx", 
                       sheet_name=3)
climate_action_df
# Out:
#          Macrotopic                                            Question  \
# 0    Climate Action   Why is sustainability risk gaining importance ...
# 1    Climate Action   Why is environmental risk, particularly climat...
# 2    Climate Action   How does climate change impact financial perfo...
# 3    Climate Action   How do EU sustainability policies address clim...
# 4    Climate Action   How are climate policy goals related to sustai...
# ..               ...                                                ...
# 769  Climate Action   How does the integration of CTA with vision as...
# 770  Climate Action   In what way can storytelling be used to mobili...
# 771  Climate Action   What are the key considerations for responsibl...
# 772  Climate Action   How do Stile et al. (2014) advocate for the pr...
# 773  Climate Action   What factors influence the identification of s...
#
#                                                 Answer                 Label   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Ethics and regulation
# 1    Environmental risk, especially climate change,...  Ethics and regulation
# 2    Studies and reports indicate that climate chan...               Analysis
# 3    EU sustainability policies address climate cha...             Management
# 4    Climate policy goals are in line with sustaina...               Strategy
# ..                                                 ...                    ...
# 769  The integration of CTA (Critical Technology As...               Analysis
# 770  Storytelling can be a powerful tool in partici...             Management
# 771  Steering et al. (2018) emphasize the importanc...                Factual
# 772  Stile et al. (2014) argue that promoting publi...  Ethics and regulation
# 773  According to Tang et al. (2019), the identific...               Analysis
#
#                                          Source Title   \
# 0    PDF1_Climate_policy_development_and_implementa...
# 1    PDF1_Climate_policy_development_and_implementa...
# 2    PDF1_Climate_policy_development_and_implementa...
# 3    PDF1_Climate_policy_development_and_implementa...
# 4    PDF1_Climate_policy_development_and_implementa...
# ..                                                 ...
# 769  Guiding visions of corporate smart city innova...
# 770  Guiding visions of corporate smart city innova...
# 771  Guiding visions of corporate smart city innova...
# 772  Guiding visions of corporate smart city innova...
# 773  Guiding visions of corporate smart city innova...
#
#                                             Source Url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 769  https://www.sciencedirect.com/science/article/...
# 770  https://www.sciencedirect.com/science/article/...
# 771  https://www.sciencedirect.com/science/article/...
# 772  https://www.sciencedirect.com/science/article/...
# 773  https://www.sciencedirect.com/science/article/...
#
#                                         Source Author
# 0    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 1    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 2    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 3    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 4    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# ..                                                 ...
# 769  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 770  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 771  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 772  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 773  Marjolein G. van der Meir, Make Fragile, J.E.W...
#
# [774 rows x 7 columns]

# %%
climate_action_df['QA'] = climate_action_df['Question'] + ' ' + climate_action_df['Answer']
climate_action_df
# Out:
#          Macrotopic                                            Question  \
# 0    Climate Action   Why is sustainability risk gaining importance ...
# 1    Climate Action   Why is environmental risk, particularly climat...
# 2    Climate Action   How does climate change impact financial perfo...
# 3    Climate Action   How do EU sustainability policies address clim...
# 4    Climate Action   How are climate policy goals related to sustai...
# ..               ...                                                ...
# 769  Climate Action   How does the integration of CTA with vision as...
# 770  Climate Action   In what way can storytelling be used to mobili...
# 771  Climate Action   What are the key considerations for responsibl...
# 772  Climate Action   How do Stile et al. (2014) advocate for the pr...
# 773  Climate Action   What factors influence the identification of s...
#
#                                                 Answer                 Label   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Ethics and regulation
# 1    Environmental risk, especially climate change,...  Ethics and regulation
# 2    Studies and reports indicate that climate chan...               Analysis
# 3    EU sustainability policies address climate cha...             Management
# 4    Climate policy goals are in line with sustaina...               Strategy
# ..                                                 ...                    ...
# 769  The integration of CTA (Critical Technology As...               Analysis
# 770  Storytelling can be a powerful tool in partici...             Management
# 771  Steering et al. (2018) emphasize the importanc...                Factual
# 772  Stile et al. (2014) argue that promoting publi...  Ethics and regulation
# 773  According to Tang et al. (2019), the identific...               Analysis
#
#                                          Source Title   \
# 0    PDF1_Climate_policy_development_and_implementa...
# 1    PDF1_Climate_policy_development_and_implementa...
# 2    PDF1_Climate_policy_development_and_implementa...
# 3    PDF1_Climate_policy_development_and_implementa...
# 4    PDF1_Climate_policy_development_and_implementa...
# ..                                                 ...
# 769  Guiding visions of corporate smart city innova...
# 770  Guiding visions of corporate smart city innova...
# 771  Guiding visions of corporate smart city innova...
# 772  Guiding visions of corporate smart city innova...
# 773  Guiding visions of corporate smart city innova...
#
#                                             Source Url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 769  https://www.sciencedirect.com/science/article/...
# 770  https://www.sciencedirect.com/science/article/...
# 771  https://www.sciencedirect.com/science/article/...
# 772  https://www.sciencedirect.com/science/article/...
# 773  https://www.sciencedirect.com/science/article/...
#
#                                         Source Author   \
# 0    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 1    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 2    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 3    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 4    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# ..                                                 ...
# 769  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 770  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 771  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 772  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 773  Marjolein G. van der Meir, Make Fragile, J.E.W...
#
#                                                     QA
# 0    Why is sustainability risk gaining importance ...
# 1    Why is environmental risk, particularly climat...
# 2    How does climate change impact financial perfo...
# 3    How do EU sustainability policies address clim...
# 4    How are climate policy goals related to sustai...
# ..                                                 ...
# 769  How does the integration of CTA with vision as...
# 770  In what way can storytelling be used to mobili...
# 771  What are the key considerations for responsibl...
# 772  How do Stile et al. (2014) advocate for the pr...
# 773  What factors influence the identification of s...
#
# [774 rows x 8 columns]

# %%
# Climate change subtopic
clmtaction_subtopic = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\Climate Change macro-topic, topic, sub-topics .xlsx", 
                                 sheet_name=2, skiprows=[1])
clmtaction_subtopic
# Out:
#                                topic   \
# 0                     Sea level rise
# 1                     Sea level rise
# 2                     Sea level rise
# 3                     Sea level rise
# 4                     Sea level rise
# ..                                ...
# 491  International climate agreements
# 492  International climate agreements
# 493  International climate agreements
# 494  International climate agreements
# 495  International climate agreements
#
#                                               Subtopic  \
# 0                                      Coastal Erosion
# 1                          Impact on Low-Lying Islands
# 2                    Threats to Coastal Infrastructure
# 3         Saltwater Intrusion into Freshwater Aquifers
# 4                             Loss of Coastal Wetlands
# ..                                                 ...
# 491                       Bilateral Climate Agreements
# 492      Role of Non-Governmental Organizations (NGOs)
# 493   United Nations Climate Change Conferences (COPs)
# 494  Indigenous Rights and Inclusion in Global Agre...
# 495  Climate Agreements and Sustainable Development...
#
#                                            Description  \
# 0    Coastal erosion involves the wearing away of l...
# 1    Low-lying islands face existential threats fro...
# 2    Rising sea levels pose risks to coastal infras...
# 3    Saltwater intrusion contaminates freshwater re...
# 4    Coastal wetlands are threatened by sea level r...
# ..                                                 ...
# 491  Agreements between two countries to work toget...
# 492  Highlighting the contributions of NGOs in shap...
# 493  Annual conferences where countries negotiate a...
# 494  Recognizing and incorporating the rights, know...
# 495  Aligning climate agreements with the broader g...
#
#                                               Keywords
# 0              coastal, erosion, protection, sea walls
# 1        low-lying islands, sea level rise, adaptation
# 2    coastal infrastructure, sea level rise, flood-...
# 3            saltwater intrusion, freshwater, aquifers
# 4          coastal wetlands, biodiversity, restoration
# ..                                                 ...
# 491  bilateral agreements, climate action, collabor...
# 492                     NGOs, climate action, advocacy
# 493                  COPs, climate change, conferences
# 494   indigenous rights, climate agreements, inclusion
# 495  climate agreements, SDGs, sustainable development
#
# [496 rows x 4 columns]

# %%
# text embedding for climate action corpus
text_embed('QA', climate_action_df, 'QA_vector')
# Out:
#          Macrotopic                                            Question  \
# 0    Climate Action   Why is sustainability risk gaining importance ...
# 1    Climate Action   Why is environmental risk, particularly climat...
# 2    Climate Action   How does climate change impact financial perfo...
# 3    Climate Action   How do EU sustainability policies address clim...
# 4    Climate Action   How are climate policy goals related to sustai...
# ..               ...                                                ...
# 769  Climate Action   How does the integration of CTA with vision as...
# 770  Climate Action   In what way can storytelling be used to mobili...
# 771  Climate Action   What are the key considerations for responsibl...
# 772  Climate Action   How do Stile et al. (2014) advocate for the pr...
# 773  Climate Action   What factors influence the identification of s...
#
#                                                 Answer                 Label   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Ethics and regulation
# 1    Environmental risk, especially climate change,...  Ethics and regulation
# 2    Studies and reports indicate that climate chan...               Analysis
# 3    EU sustainability policies address climate cha...             Management
# 4    Climate policy goals are in line with sustaina...               Strategy
# ..                                                 ...                    ...
# 769  The integration of CTA (Critical Technology As...               Analysis
# 770  Storytelling can be a powerful tool in partici...             Management
# 771  Steering et al. (2018) emphasize the importanc...                Factual
# 772  Stile et al. (2014) argue that promoting publi...  Ethics and regulation
# 773  According to Tang et al. (2019), the identific...               Analysis
#
#                                          Source Title   \
# 0    PDF1_Climate_policy_development_and_implementa...
# 1    PDF1_Climate_policy_development_and_implementa...
# 2    PDF1_Climate_policy_development_and_implementa...
# 3    PDF1_Climate_policy_development_and_implementa...
# 4    PDF1_Climate_policy_development_and_implementa...
# ..                                                 ...
# 769  Guiding visions of corporate smart city innova...
# 770  Guiding visions of corporate smart city innova...
# 771  Guiding visions of corporate smart city innova...
# 772  Guiding visions of corporate smart city innova...
# 773  Guiding visions of corporate smart city innova...
#
#                                             Source Url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 769  https://www.sciencedirect.com/science/article/...
# 770  https://www.sciencedirect.com/science/article/...
# 771  https://www.sciencedirect.com/science/article/...
# 772  https://www.sciencedirect.com/science/article/...
# 773  https://www.sciencedirect.com/science/article/...
#
#                                         Source Author   \
# 0    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 1    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 2    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 3    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 4    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# ..                                                 ...
# 769  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 770  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 771  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 772  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 773  Marjolein G. van der Meir, Make Fragile, J.E.W...
#
#                                                     QA  \
# 0    Why is sustainability risk gaining importance ...
# 1    Why is environmental risk, particularly climat...
# 2    How does climate change impact financial perfo...
# 3    How do EU sustainability policies address clim...
# 4    How are climate policy goals related to sustai...
# ..                                                 ...
# 769  How does the integration of CTA with vision as...
# 770  In what way can storytelling be used to mobili...
# 771  What are the key considerations for responsibl...
# 772  How do Stile et al. (2014) advocate for the pr...
# 773  What factors influence the identification of s...
#
#                                              QA_vector
# 0    [-0.015575544, -0.017865686, 0.012622053, -0.0...
# 1    [0.012294093, -0.027403206, 0.043451298, 0.006...
# 2    [-0.015295985, -0.010350421, 0.06548612, 0.036...
# 3    [-0.023361845, -0.013595292, 0.017625155, -0.0...
# 4    [-0.0035610863, -0.0016003839, 0.042024367, -0...
# ..                                                 ...
# 769  [-0.02345577, 0.0058976845, 0.04266114, -0.027...
# 770  [0.040761076, -0.03606351, 0.038470004, -0.008...
# 771  [-0.017144602, -0.027038224, 0.061683625, -0.0...
# 772  [-0.03248833, 0.020769533, 0.023415921, -0.038...
# 773  [-0.0097972425, 0.025939211, 0.045996543, -0.0...
#
# [774 rows x 9 columns]

# %%
# subtopic embedding for climate change
text_embed('Description', clmtaction_subtopic, 'Des_vector')
clmtaction_subtopic
# Out:
#                                topic   \
# 0                     Sea level rise
# 1                     Sea level rise
# 2                     Sea level rise
# 3                     Sea level rise
# 4                     Sea level rise
# ..                                ...
# 491  International climate agreements
# 492  International climate agreements
# 493  International climate agreements
# 494  International climate agreements
# 495  International climate agreements
#
#                                               Subtopic  \
# 0                                      Coastal Erosion
# 1                          Impact on Low-Lying Islands
# 2                    Threats to Coastal Infrastructure
# 3         Saltwater Intrusion into Freshwater Aquifers
# 4                             Loss of Coastal Wetlands
# ..                                                 ...
# 491                       Bilateral Climate Agreements
# 492      Role of Non-Governmental Organizations (NGOs)
# 493   United Nations Climate Change Conferences (COPs)
# 494  Indigenous Rights and Inclusion in Global Agre...
# 495  Climate Agreements and Sustainable Development...
#
#                                            Description  \
# 0    Coastal erosion involves the wearing away of l...
# 1    Low-lying islands face existential threats fro...
# 2    Rising sea levels pose risks to coastal infras...
# 3    Saltwater intrusion contaminates freshwater re...
# 4    Coastal wetlands are threatened by sea level r...
# ..                                                 ...
# 491  Agreements between two countries to work toget...
# 492  Highlighting the contributions of NGOs in shap...
# 493  Annual conferences where countries negotiate a...
# 494  Recognizing and incorporating the rights, know...
# 495  Aligning climate agreements with the broader g...
#
#                                               Keywords  \
# 0              coastal, erosion, protection, sea walls
# 1        low-lying islands, sea level rise, adaptation
# 2    coastal infrastructure, sea level rise, flood-...
# 3            saltwater intrusion, freshwater, aquifers
# 4          coastal wetlands, biodiversity, restoration
# ..                                                 ...
# 491  bilateral agreements, climate action, collabor...
# 492                     NGOs, climate action, advocacy
# 493                  COPs, climate change, conferences
# 494   indigenous rights, climate agreements, inclusion
# 495  climate agreements, SDGs, sustainable development
#
#                                             Des_vector
# 0    [-0.031825434, -0.012220559, 0.037745282, -0.0...
# 1    [-0.055055037, 0.0029631474, 0.008831218, 0.00...
# 2    [-0.03478838, -0.03702223, 0.04551968, -0.0298...
# 3    [-0.033366896, -0.043829467, 0.051283106, -0.0...
# 4    [-0.0031436805, -0.010280124, 0.02047494, -0.0...
# ..                                                 ...
# 491  [-0.057403196, 0.004895146, 0.052354258, 0.004...
# 492  [-0.049948506, 0.014424108, 0.026244527, -0.01...
# 493  [-0.05309704, -0.015367571, 0.019939508, 0.031...
# 494  [-0.015862292, 0.0067283413, 0.049751773, 0.01...
# 495  [-0.04982485, -0.024703652, 0.050765403, 0.004...
#
# [496 rows x 5 columns]

# %%
# Subtopic assignment for climate change dataset
assign_subtopic(climate_action_df, 'QA_vector', clmtaction_subtopic, clmtaction_subtopic['Des_vector'], 'Subtopic', 'Assigned Subtopic')

# %%
climate_action_df
# Out:
#          Macrotopic                                            Question  \
# 0    Climate Action   Why is sustainability risk gaining importance ...
# 1    Climate Action   Why is environmental risk, particularly climat...
# 2    Climate Action   How does climate change impact financial perfo...
# 3    Climate Action   How do EU sustainability policies address clim...
# 4    Climate Action   How are climate policy goals related to sustai...
# ..               ...                                                ...
# 769  Climate Action   How does the integration of CTA with vision as...
# 770  Climate Action   In what way can storytelling be used to mobili...
# 771  Climate Action   What are the key considerations for responsibl...
# 772  Climate Action   How do Stile et al. (2014) advocate for the pr...
# 773  Climate Action   What factors influence the identification of s...
#
#                                                 Answer                 Label   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Ethics and regulation
# 1    Environmental risk, especially climate change,...  Ethics and regulation
# 2    Studies and reports indicate that climate chan...               Analysis
# 3    EU sustainability policies address climate cha...             Management
# 4    Climate policy goals are in line with sustaina...               Strategy
# ..                                                 ...                    ...
# 769  The integration of CTA (Critical Technology As...               Analysis
# 770  Storytelling can be a powerful tool in partici...             Management
# 771  Steering et al. (2018) emphasize the importanc...                Factual
# 772  Stile et al. (2014) argue that promoting publi...  Ethics and regulation
# 773  According to Tang et al. (2019), the identific...               Analysis
#
#                                          Source Title   \
# 0    PDF1_Climate_policy_development_and_implementa...
# 1    PDF1_Climate_policy_development_and_implementa...
# 2    PDF1_Climate_policy_development_and_implementa...
# 3    PDF1_Climate_policy_development_and_implementa...
# 4    PDF1_Climate_policy_development_and_implementa...
# ..                                                 ...
# 769  Guiding visions of corporate smart city innova...
# 770  Guiding visions of corporate smart city innova...
# 771  Guiding visions of corporate smart city innova...
# 772  Guiding visions of corporate smart city innova...
# 773  Guiding visions of corporate smart city innova...
#
#                                             Source Url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 769  https://www.sciencedirect.com/science/article/...
# 770  https://www.sciencedirect.com/science/article/...
# 771  https://www.sciencedirect.com/science/article/...
# 772  https://www.sciencedirect.com/science/article/...
# 773  https://www.sciencedirect.com/science/article/...
#
#                                         Source Author   \
# 0    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 1    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 2    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 3    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 4    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# ..                                                 ...
# 769  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 770  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 771  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 772  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 773  Marjolein G. van der Meir, Make Fragile, J.E.W...
#
#                                                     QA  \
# 0    Why is sustainability risk gaining importance ...
# 1    Why is environmental risk, particularly climat...
# 2    How does climate change impact financial perfo...
# 3    How do EU sustainability policies address clim...
# 4    How are climate policy goals related to sustai...
# ..                                                 ...
# 769  How does the integration of CTA with vision as...
# 770  In what way can storytelling be used to mobili...
# 771  What are the key considerations for responsibl...
# 772  How do Stile et al. (2014) advocate for the pr...
# 773  What factors influence the identification of s...
#
#                                              QA_vector  \
# 0    [-0.015575544, -0.017865686, 0.012622053, -0.0...
# 1    [0.012294093, -0.027403206, 0.043451298, 0.006...
# 2    [-0.015295985, -0.010350421, 0.06548612, 0.036...
# 3    [-0.023361845, -0.013595292, 0.017625155, -0.0...
# 4    [-0.0035610863, -0.0016003839, 0.042024367, -0...
# ..                                                 ...
# 769  [-0.02345577, 0.0058976845, 0.04266114, -0.027...
# 770  [0.040761076, -0.03606351, 0.038470004, -0.008...
# 771  [-0.017144602, -0.027038224, 0.061683625, -0.0...
# 772  [-0.03248833, 0.020769533, 0.023415921, -0.038...
# 773  [-0.0097972425, 0.025939211, 0.045996543, -0.0...
#
#                                                QA_prep  \
# 0    sustainability risk gaining importance busines...
# 1    environmental risk particularly climate change...
# 2    climate change impact financial performance ac...
# 3    eu sustainability policies address climate cha...
# 4    climate policy goals related sustainable devel...
# ..                                                 ...
# 769  integration cta vision assessment help explore...
# 770  way storytelling used mobilize situated local ...
# 771  key considerations responsible governance inno...
# 772  stile et al advocate promotion public engageme...
# 773  factors influence identification smart city ar...
#
#                                         QA_prep_vector  \
# 0    [-0.021073606, -0.039178837, 0.015091247, -0.0...
# 1    [0.0008381564, -0.03459547, 0.05423817, 0.0094...
# 2    [-0.017736359, -0.007898038, 0.0696104, 0.0370...
# 3    [-0.029540634, -0.00070302305, 0.020287389, -0...
# 4    [-0.023365559, 0.0012606684, 0.065723896, -0.0...
# ..                                                 ...
# 769  [-0.02349394, 0.008930604, 0.038689557, -0.022...
# 770  [0.030992633, -0.030203486, 0.045347907, -0.00...
# 771  [-0.03359087, -0.026973063, 0.058436006, -0.05...
# 772  [-0.024278762, 0.028534295, 0.0331938, -0.0421...
# 773  [-0.008698104, 0.017330654, 0.050830945, -0.04...
#
#                        Assigned Subtopic(Preprocessed)  \
# 0                           Financial Viability of CCS
# 1                  Intense Rainfall and Flash Flooding
# 2                        Changes in Windstorm Patterns
# 3             Green Finance for GHG Reduction Projects
# 4               Global Greenhouse Gas Emission Targets
# ..                                                 ...
# 769                                                NaN
# 770               Localized Climate Action Initiatives
# 771                                                NaN
# 772  Role of Citizen Science in Biodiversity Monito...
# 773                                                NaN
#
#                                      Assigned Subtopic
# 0                                                  NaN
# 1                        Ice Cap and Glacier Mass Loss
# 2                        Climate-Resilient Livelihoods
# 3               Promotion of Renewable Energy Policies
# 4    Climate Agreements and Sustainable Development...
# ..                                                 ...
# 769      Role of Technology in Biodiversity Monitoring
# 770               Localized Climate Action Initiatives
# 771                                                NaN
# 772  Role of Citizen Science in Biodiversity Monito...
# 773                                                NaN
#
# [774 rows x 13 columns]

# %%
climate_action_df['QA_prep'] = climate_action_df['QA'].apply(preprocess_text)

# %%
clmtaction_subtopic['Des_prep'] = clmtaction_subtopic['Description'].apply(preprocess_text)

# %%
# text embedding for preprocessed climate change corpus
text_embed('QA_prep', climate_action_df, 'QA_prep_vector')
# Out:
#          Macrotopic                                            Question  \
# 0    Climate Action   Why is sustainability risk gaining importance ...
# 1    Climate Action   Why is environmental risk, particularly climat...
# 2    Climate Action   How does climate change impact financial perfo...
# 3    Climate Action   How do EU sustainability policies address clim...
# 4    Climate Action   How are climate policy goals related to sustai...
# ..               ...                                                ...
# 769  Climate Action   How does the integration of CTA with vision as...
# 770  Climate Action   In what way can storytelling be used to mobili...
# 771  Climate Action   What are the key considerations for responsibl...
# 772  Climate Action   How do Stile et al. (2014) advocate for the pr...
# 773  Climate Action   What factors influence the identification of s...
#
#                                                 Answer                 Label   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Ethics and regulation
# 1    Environmental risk, especially climate change,...  Ethics and regulation
# 2    Studies and reports indicate that climate chan...               Analysis
# 3    EU sustainability policies address climate cha...             Management
# 4    Climate policy goals are in line with sustaina...               Strategy
# ..                                                 ...                    ...
# 769  The integration of CTA (Critical Technology As...               Analysis
# 770  Storytelling can be a powerful tool in partici...             Management
# 771  Steering et al. (2018) emphasize the importanc...                Factual
# 772  Stile et al. (2014) argue that promoting publi...  Ethics and regulation
# 773  According to Tang et al. (2019), the identific...               Analysis
#
#                                          Source Title   \
# 0    PDF1_Climate_policy_development_and_implementa...
# 1    PDF1_Climate_policy_development_and_implementa...
# 2    PDF1_Climate_policy_development_and_implementa...
# 3    PDF1_Climate_policy_development_and_implementa...
# 4    PDF1_Climate_policy_development_and_implementa...
# ..                                                 ...
# 769  Guiding visions of corporate smart city innova...
# 770  Guiding visions of corporate smart city innova...
# 771  Guiding visions of corporate smart city innova...
# 772  Guiding visions of corporate smart city innova...
# 773  Guiding visions of corporate smart city innova...
#
#                                             Source Url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 769  https://www.sciencedirect.com/science/article/...
# 770  https://www.sciencedirect.com/science/article/...
# 771  https://www.sciencedirect.com/science/article/...
# 772  https://www.sciencedirect.com/science/article/...
# 773  https://www.sciencedirect.com/science/article/...
#
#                                         Source Author   \
# 0    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 1    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 2    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 3    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 4    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# ..                                                 ...
# 769  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 770  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 771  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 772  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 773  Marjolein G. van der Meir, Make Fragile, J.E.W...
#
#                                                     QA  \
# 0    Why is sustainability risk gaining importance ...
# 1    Why is environmental risk, particularly climat...
# 2    How does climate change impact financial perfo...
# 3    How do EU sustainability policies address clim...
# 4    How are climate policy goals related to sustai...
# ..                                                 ...
# 769  How does the integration of CTA with vision as...
# 770  In what way can storytelling be used to mobili...
# 771  What are the key considerations for responsibl...
# 772  How do Stile et al. (2014) advocate for the pr...
# 773  What factors influence the identification of s...
#
#                                              QA_vector  \
# 0    [-0.015575544, -0.017865686, 0.012622053, -0.0...
# 1    [0.012294093, -0.027403206, 0.043451298, 0.006...
# 2    [-0.015295985, -0.010350421, 0.06548612, 0.036...
# 3    [-0.023361845, -0.013595292, 0.017625155, -0.0...
# 4    [-0.0035610863, -0.0016003839, 0.042024367, -0...
# ..                                                 ...
# 769  [-0.02345577, 0.0058976845, 0.04266114, -0.027...
# 770  [0.040761076, -0.03606351, 0.038470004, -0.008...
# 771  [-0.017144602, -0.027038224, 0.061683625, -0.0...
# 772  [-0.03248833, 0.020769533, 0.023415921, -0.038...
# 773  [-0.0097972425, 0.025939211, 0.045996543, -0.0...
#
#                                                QA_prep  \
# 0    sustainability risk gaining importance busines...
# 1    environmental risk particularly climate change...
# 2    climate change impact financial performance ac...
# 3    eu sustainability policies address climate cha...
# 4    climate policy goals related sustainable devel...
# ..                                                 ...
# 769  integration cta vision assessment help explore...
# 770  way storytelling used mobilize situated local ...
# 771  key considerations responsible governance inno...
# 772  stile et al advocate promotion public engageme...
# 773  factors influence identification smart city ar...
#
#                                         QA_prep_vector
# 0    [-0.021073606, -0.039178837, 0.015091247, -0.0...
# 1    [0.0008381564, -0.03459547, 0.05423817, 0.0094...
# 2    [-0.017736359, -0.007898038, 0.0696104, 0.0370...
# 3    [-0.029540634, -0.00070302305, 0.020287389, -0...
# 4    [-0.023365559, 0.0012606684, 0.065723896, -0.0...
# ..                                                 ...
# 769  [-0.02349394, 0.008930604, 0.038689557, -0.022...
# 770  [0.030992633, -0.030203486, 0.045347907, -0.00...
# 771  [-0.03359087, -0.026973063, 0.058436006, -0.05...
# 772  [-0.024278762, 0.028534295, 0.0331938, -0.0421...
# 773  [-0.008698104, 0.017330654, 0.050830945, -0.04...
#
# [774 rows x 11 columns]

# %%
# subtopic embedding for preprocessed climate change description
text_embed('Des_prep', clmtaction_subtopic, 'Des_prep_vector')
# Out:
#                                topic   \
# 0                     Sea level rise
# 1                     Sea level rise
# 2                     Sea level rise
# 3                     Sea level rise
# 4                     Sea level rise
# ..                                ...
# 491  International climate agreements
# 492  International climate agreements
# 493  International climate agreements
# 494  International climate agreements
# 495  International climate agreements
#
#                                               Subtopic  \
# 0                                      Coastal Erosion
# 1                          Impact on Low-Lying Islands
# 2                    Threats to Coastal Infrastructure
# 3         Saltwater Intrusion into Freshwater Aquifers
# 4                             Loss of Coastal Wetlands
# ..                                                 ...
# 491                       Bilateral Climate Agreements
# 492      Role of Non-Governmental Organizations (NGOs)
# 493   United Nations Climate Change Conferences (COPs)
# 494  Indigenous Rights and Inclusion in Global Agre...
# 495  Climate Agreements and Sustainable Development...
#
#                                            Description  \
# 0    Coastal erosion involves the wearing away of l...
# 1    Low-lying islands face existential threats fro...
# 2    Rising sea levels pose risks to coastal infras...
# 3    Saltwater intrusion contaminates freshwater re...
# 4    Coastal wetlands are threatened by sea level r...
# ..                                                 ...
# 491  Agreements between two countries to work toget...
# 492  Highlighting the contributions of NGOs in shap...
# 493  Annual conferences where countries negotiate a...
# 494  Recognizing and incorporating the rights, know...
# 495  Aligning climate agreements with the broader g...
#
#                                               Keywords  \
# 0              coastal, erosion, protection, sea walls
# 1        low-lying islands, sea level rise, adaptation
# 2    coastal infrastructure, sea level rise, flood-...
# 3            saltwater intrusion, freshwater, aquifers
# 4          coastal wetlands, biodiversity, restoration
# ..                                                 ...
# 491  bilateral agreements, climate action, collabor...
# 492                     NGOs, climate action, advocacy
# 493                  COPs, climate change, conferences
# 494   indigenous rights, climate agreements, inclusion
# 495  climate agreements, SDGs, sustainable development
#
#                                             Des_vector  \
# 0    [-0.031825434, -0.012220559, 0.037745282, -0.0...
# 1    [-0.055055037, 0.0029631474, 0.008831218, 0.00...
# 2    [-0.03478838, -0.03702223, 0.04551968, -0.0298...
# 3    [-0.033366896, -0.043829467, 0.051283106, -0.0...
# 4    [-0.0031436805, -0.010280124, 0.02047494, -0.0...
# ..                                                 ...
# 491  [-0.057403196, 0.004895146, 0.052354258, 0.004...
# 492  [-0.049948506, 0.014424108, 0.026244527, -0.01...
# 493  [-0.05309704, -0.015367571, 0.019939508, 0.031...
# 494  [-0.015862292, 0.0067283413, 0.049751773, 0.01...
# 495  [-0.04982485, -0.024703652, 0.050765403, 0.004...
#
#                                               Des_prep  \
# 0    coastal erosion involves wearing away land rem...
# 1    lowlying islands face existential threats risi...
# 2    rising sea levels pose risks coastal infrastru...
# 3    saltwater intrusion contaminates freshwater re...
# 4    coastal wetlands threatened sea level rise lea...
# ..                                                 ...
# 491  agreements two countries work together specifi...
# 492  highlighting contributions ngos shaping advoca...
# 493  annual conferences countries negotiate assess ...
# 494  recognizing incorporating rights knowledge per...
# 495  aligning climate agreements broader goals sust...
#
#                                        Des_prep_vector
# 0    [-0.02868289, -0.0055619627, 0.026282977, -0.0...
# 1    [-0.050886992, -0.009998705, 0.0025397737, -0....
# 2    [-0.028306216, -0.037292987, 0.04857379, -0.03...
# 3    [-0.046043143, -0.03874169, 0.042635817, -0.00...
# 4    [-0.012325102, -0.012568952, 0.025065618, -0.0...
# ..                                                 ...
# 491  [-0.056429412, 0.009538388, 0.057691716, 0.002...
# 492  [-0.06789759, 0.012626651, 0.007876329, -0.026...
# 493  [-0.062138118, 0.0054841363, 0.023442823, 0.03...
# 494  [-0.03817889, 0.01594308, 0.053786807, -0.0073...
# 495  [-0.07390894, -0.012641688, 0.06799568, -0.011...
#
# [496 rows x 7 columns]

# %%
#Subtopic assignment for smart cities dataset
assign_subtopic(climate_action_df, 'QA_prep_vector', clmtaction_subtopic, clmtaction_subtopic['Des_prep_vector'], 'Subtopic', 'Assigned Subtopic(Preprocessed)')

# %%
climate_action_df
# Out:
#          Macrotopic                                            Question  \
# 0    Climate Action   Why is sustainability risk gaining importance ...
# 1    Climate Action   Why is environmental risk, particularly climat...
# 2    Climate Action   How does climate change impact financial perfo...
# 3    Climate Action   How do EU sustainability policies address clim...
# 4    Climate Action   How are climate policy goals related to sustai...
# ..               ...                                                ...
# 769  Climate Action   How does the integration of CTA with vision as...
# 770  Climate Action   In what way can storytelling be used to mobili...
# 771  Climate Action   What are the key considerations for responsibl...
# 772  Climate Action   How do Stile et al. (2014) advocate for the pr...
# 773  Climate Action   What factors influence the identification of s...
#
#                                                 Answer                 Label   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Ethics and regulation
# 1    Environmental risk, especially climate change,...  Ethics and regulation
# 2    Studies and reports indicate that climate chan...               Analysis
# 3    EU sustainability policies address climate cha...             Management
# 4    Climate policy goals are in line with sustaina...               Strategy
# ..                                                 ...                    ...
# 769  The integration of CTA (Critical Technology As...               Analysis
# 770  Storytelling can be a powerful tool in partici...             Management
# 771  Steering et al. (2018) emphasize the importanc...                Factual
# 772  Stile et al. (2014) argue that promoting publi...  Ethics and regulation
# 773  According to Tang et al. (2019), the identific...               Analysis
#
#                                          Source Title   \
# 0    PDF1_Climate_policy_development_and_implementa...
# 1    PDF1_Climate_policy_development_and_implementa...
# 2    PDF1_Climate_policy_development_and_implementa...
# 3    PDF1_Climate_policy_development_and_implementa...
# 4    PDF1_Climate_policy_development_and_implementa...
# ..                                                 ...
# 769  Guiding visions of corporate smart city innova...
# 770  Guiding visions of corporate smart city innova...
# 771  Guiding visions of corporate smart city innova...
# 772  Guiding visions of corporate smart city innova...
# 773  Guiding visions of corporate smart city innova...
#
#                                             Source Url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 769  https://www.sciencedirect.com/science/article/...
# 770  https://www.sciencedirect.com/science/article/...
# 771  https://www.sciencedirect.com/science/article/...
# 772  https://www.sciencedirect.com/science/article/...
# 773  https://www.sciencedirect.com/science/article/...
#
#                                         Source Author   \
# 0    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 1    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 2    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 3    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# 4    Krzysztof Plaza a, Magdalena Solo b, Marta Pos...
# ..                                                 ...
# 769  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 770  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 771  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 772  Marjolein G. van der Meir, Make Fragile, J.E.W...
# 773  Marjolein G. van der Meir, Make Fragile, J.E.W...
#
#                                                     QA  \
# 0    Why is sustainability risk gaining importance ...
# 1    Why is environmental risk, particularly climat...
# 2    How does climate change impact financial perfo...
# 3    How do EU sustainability policies address clim...
# 4    How are climate policy goals related to sustai...
# ..                                                 ...
# 769  How does the integration of CTA with vision as...
# 770  In what way can storytelling be used to mobili...
# 771  What are the key considerations for responsibl...
# 772  How do Stile et al. (2014) advocate for the pr...
# 773  What factors influence the identification of s...
#
#                                              QA_vector  \
# 0    [-0.015575544, -0.017865686, 0.012622053, -0.0...
# 1    [0.012294093, -0.027403206, 0.043451298, 0.006...
# 2    [-0.015295985, -0.010350421, 0.06548612, 0.036...
# 3    [-0.023361845, -0.013595292, 0.017625155, -0.0...
# 4    [-0.0035610863, -0.0016003839, 0.042024367, -0...
# ..                                                 ...
# 769  [-0.02345577, 0.0058976845, 0.04266114, -0.027...
# 770  [0.040761076, -0.03606351, 0.038470004, -0.008...
# 771  [-0.017144602, -0.027038224, 0.061683625, -0.0...
# 772  [-0.03248833, 0.020769533, 0.023415921, -0.038...
# 773  [-0.0097972425, 0.025939211, 0.045996543, -0.0...
#
#                                                QA_prep  \
# 0    sustainability risk gaining importance busines...
# 1    environmental risk particularly climate change...
# 2    climate change impact financial performance ac...
# 3    eu sustainability policies address climate cha...
# 4    climate policy goals related sustainable devel...
# ..                                                 ...
# 769  integration cta vision assessment help explore...
# 770  way storytelling used mobilize situated local ...
# 771  key considerations responsible governance inno...
# 772  stile et al advocate promotion public engageme...
# 773  factors influence identification smart city ar...
#
#                                         QA_prep_vector  \
# 0    [-0.021073606, -0.039178837, 0.015091247, -0.0...
# 1    [0.0008381564, -0.03459547, 0.05423817, 0.0094...
# 2    [-0.017736359, -0.007898038, 0.0696104, 0.0370...
# 3    [-0.029540634, -0.00070302305, 0.020287389, -0...
# 4    [-0.023365559, 0.0012606684, 0.065723896, -0.0...
# ..                                                 ...
# 769  [-0.02349394, 0.008930604, 0.038689557, -0.022...
# 770  [0.030992633, -0.030203486, 0.045347907, -0.00...
# 771  [-0.03359087, -0.026973063, 0.058436006, -0.05...
# 772  [-0.024278762, 0.028534295, 0.0331938, -0.0421...
# 773  [-0.008698104, 0.017330654, 0.050830945, -0.04...
#
#                        Assigned Subtopic(Preprocessed)
# 0                           Financial Viability of CCS
# 1                  Intense Rainfall and Flash Flooding
# 2                        Changes in Windstorm Patterns
# 3             Green Finance for GHG Reduction Projects
# 4               Global Greenhouse Gas Emission Targets
# ..                                                 ...
# 769                                                NaN
# 770               Localized Climate Action Initiatives
# 771                                                NaN
# 772  Role of Citizen Science in Biodiversity Monito...
# 773                                                NaN
#
# [774 rows x 12 columns]

# %%
subs_climatechg = pd.read_excel(r"C:\Users\RedHat\Downloads\Tiiqu\Climate Change macro-topic, topic, sub-topics .xlsx", 
                                 sheet_name=0)
subs_climatechg
# Out:
#                                 Global Warming  \
# 0                     Greenhouse Gas Emissions
# 1           Rising Average Global Temperatures
# 2                     Impact on Polar Ice Caps
# 3                   Ocean Temperature Increase
# 4                     Extreme Weather Patterns
# 5              Melting Glaciers and Ice Sheets
# 6                               Sea Level Rise
# 7         Heatwaves and Heat-Related Illnesses
# 8                          Ocean Acidification
# 9        Shifts in Wildlife Migration Patterns
# 10                    Disruption of Ecosystems
# 11    Effects on Agriculture and Food Security
# 12                      Threats to Coral Reefs
# 13  Increased Intensity of Hurricanes/Cyclones
# 14     Impact on Arctic and Antarctic Wildlife
# 15      Permafrost Thaw and Release of Methane
# 16             Rising Sea Surface Temperatures
# 17                     Threats to Biodiversity
# 18                Changes in Ocean Circulation
# 19               Impact on Coastal Communities
# 20             Spread of Vector-Borne Diseases
# 21                         Acid Rain Formation
# 22                 Changes in Weather Extremes
# 23                Altered Patterns of Snowfall
# 24                  Risks to Low-Lying Islands
# 25                       Ocean Current Changes
# 26                 Shifts in Wildlife Habitats
# 27       Challenges for Indigenous Communities
# 28                                         NaN
# 29                                         NaN
#
#                                        Sea Level Rise  \
# 0                                     Coastal Erosion
# 1                         Impact on Low-Lying Islands
# 2                   Threats to Coastal Infrastructure
# 3        Saltwater Intrusion into Freshwater Aquifers
# 4                            Loss of Coastal Wetlands
# 5                           Increased Flooding Events
# 6                      Effects on Coastal Agriculture
# 7                    Migration of Coastal Communities
# 8                     Changes in Coastal Biodiversity
# 9                              Altered Ocean Currents
# 10                  Influence on Coastal Storm Surges
# 11                          Changes in Tidal Patterns
# 12                            Sea Level Rise Modeling
# 13                 Coastal Zone Management Strategies
# 14              Threats to Coastal Ecosystem Services
# 15                    Coastal Infrastructure planning
# 16             Adaptation Measures for Coastal Cities
# 17                   Impact on Global Shipping Routes
# 18                            Ocean Thermal Expansion
# 19                     Changes in Coastal Aquaculture
# 20                      Impact on Mangrove Ecosystems
# 21         Rising Groundwater Tables in Coastal Areas
# 22       Socioeconomic Impacts on Coastal Communities
# 23       Legal and Policy Responses to Sea Level Rise
# 24  Role of urban planning  in Sea Level Rise Miti...
# 25        Technology Solutions for Coastal Protection
# 26  International Collaboration for Coastal Resili...
# 27               Monitoring and Early Warning Systems
# 28                          Impact on Coastal Tourism
# 29                                                NaN
#
#                     Carbon Footprint Reduction  \
# 0                    Renewable Energy Adoption
# 1              Energy-Efficient Transportation
# 2                    Green building  Practices
# 3                 circular Economy Initiatives
# 4              Afforestation and Reforestation
# 5            Sustainable Agriculture Practices
# 6                Eco-friendly Consumer Choices
# 7                       Carbon offset Programs
# 8                  Energy-Efficient Appliances
# 9                 Sustainable Waste Management
# 10          Low-carbon Manufacturing Processes
# 11                 Green Technology Innovation
# 12             Public Transportation Promotion
# 13              Eco-friendly Commuting Options
# 14          Sustainable Supply Chain Practices
# 15       Carbon-Neutral Events and Conferences
# 16  Conservation and Restoration of Ecosystems
# 17                Sustainable Water Management
# 18                  carbon pricing  Mechanisms
# 19             Eco-friendly Travel and Tourism
# 20        Corporate Sustainability Initiatives
# 21                    Adoption of LED Lighting
# 22      Promotion of Renewable Energy Policies
# 23       Eco-conscious Education and Awareness
# 24     Green Finance and Investment Strategies
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
#
#               Sustainable Agriculture Practices  \
# 0            Precision Agriculture Technologies
# 1                       Organic Farming Methods
# 2               Conservation Tillage Techniques
# 3              Drought-Resistant crop Varieties
# 4            Water-Efficient Irrigation Systems
# 5                     Soil Carbon Sequestration
# 6              Cover Cropping and crop Rotation
# 7              Integrated Pest Management (IPM)
# 8                  Climate-Smart crop Selection
# 9                 Sustainable Livestock Farming
# 10                Agrobiodiversity Conservation
# 11          Eco-friendly Fertilizer Application
# 12       Vertical Farming and Urban Agriculture
# 13                     Carbon Farming Practices
# 14                      No-Till Farming Systems
# 15                   Aquaponics and Hydroponics
# 16                      Sustainable Aquaculture
# 17        Community-Supported Agriculture (CSA)
# 18             Agricultural Resilience Planning
# 19  Renewable Energy Integration in Agriculture
# 20                  Precision Livestock Farming
# 21          Adoption of Climate-Resilient Seeds
# 22        Soil Health Monitoring and Management
# 23                    Biodiverse Agroecosystems
# 24  Sustainable Water Management in Agriculture
# 25               Carbon Trading for Agriculture
# 26              Climate-Adaptive crop Insurance
# 27      Remote Sensing in Precision Agriculture
# 28        Sustainable Food Distribution Systems
# 29                                          NaN
#
#                       Deforestation and Reforestation  \
# 0                    Tropical Rainforest Conservation
# 1                   Impact of Logging on Biodiversity
# 2                           Afforestation Initiatives
# 3            Causes and Consequences of Deforestation
# 4                      Reforestation as a Carbon Sink
# 5                       Sustainable Logging Practices
# 6                       Forest Restoration Techniques
# 7         Indigenous Practices in Forest Conservation
# 8                        Urban Reforestation Programs
# 9               Agroforestry for Sustainable Land Use
# 10                        Forest Carbon Sequestration
# 11                  Economic Drivers of Deforestation
# 12             Biodiversity Hotspots and Conservation
# 13              Forest Fire Prevention and Management
# 14                       Forest Landscape Restoration
# 15             Indigenous Rights in Forest Protection
# 16        Remote Sensing for Deforestation Monitoring
# 17             Community-based Reforestation Projects
# 18             Ecosystem Services Provided by Forests
# 19                   Carbon Markets and Reforestation
# 20                     Climate Resilient Tree Species
# 21          Role of Forests in Water Cycle Regulation
# 22                     Illegal Logging and Its Impact
# 23                      Forest Certification Programs
# 24                         Boreal Forest Conservation
# 25                       Wildlife Corridor Protection
# 26  Role of Reforestation in Wildlife Habitat Rest...
# 27               Payment for Ecosystem Services (PES)
# 28            Socioeconomic Benefits of Reforestation
# 29                                                NaN
#
#                 Melting Ice Caps and Glaciers  \
# 0                      Arctic Sea Ice Retreat
# 1                Antarctic Ice Sheet Dynamics
# 2                        Glacier Mass Balance
# 3                          Permafrost Thawing
# 4                      Glacier Calving Events
# 5              Iceberg Formation and Movement
# 6                    Impact on Sea Level Rise
# 7           Changes in Glacier Surface Albedo
# 8             Glacier Monitoring Technologies
# 9   Glacier Meltwater Contributions to Oceans
# 10              Ice Cap and Glacier Mass Loss
# 11                Subglacial Lake Exploration
# 12                 Glacier-Induced Landslides
# 13         Ice Sheet Modeling and Projections
# 14                      Glacier Flow Dynamics
# 15               Glacial Isostatic Adjustment
# 16             Influence on Ocean Circulation
# 17                   Glacier Retreat Patterns
# 18        Ice Algae and Microbial Communities
# 19                  Glacier Ecosystem Changes
# 20      Ice Core Research for Climate History
# 21                     Ice-Ocean Interactions
# 22       Impact on Arctic and Antarctic Fauna
# 23                Ice Meltwater River Systems
# 24   Glacier Tourism and Environmental Impact
# 25              Glacier Monitoring from Space
# 26       Glacial Lake Outburst Floods (GLOFs)
# 27   Ice Cap and Glacier Conservation Efforts
# 28                  Permafrost Carbon Release
# 29        Glacier Archaeology and Discoveries
#
#                              Extreme Weather Events  \
# 0                     Intensification of Hurricanes
# 1                  Increased Frequency of Heatwaves
# 2                 Changes in Precipitation Patterns
# 3                       Coastal and Inland Flooding
# 4                  Wildfire Intensity and Frequency
# 5                        Tropical Cyclone Intensity
# 6                       Changes in Tornado Patterns
# 7                      Expansion of Desertification
# 8                         Impact on Monsoon Systems
# 9                      Changes in Snowfall Patterns
# 10                Sea Surface Temperature Anomalies
# 11                        Urban Heat Island Effects
# 12              Intense Rainfall and Flash Flooding
# 13                 Changes in Thunderstorm Patterns
# 14             Altered El Niño and La Niña Patterns
# 15               Changes in Atmospheric Circulation
# 16                      Heat-Related Health Impacts
# 17           Impact on Agricultural Growing Seasons
# 18                  Intensification of Storm Surges
# 19                         Changes in Winter Storms
# 20                Melting Permafrost and Landslides
# 21                          Polar Vortex Disruption
# 22                           Impact on Biodiversity
# 23                    Changes in Hailstorm Patterns
# 24                         Shifts in Ocean Currents
# 25                   Changes in Dust and Sandstorms
# 26                    Changes in Atmospheric Rivers
# 27                    Changes in Windstorm Patterns
# 28  Changes in Glacial Lake Outburst Floods (GLOFs)
# 29              Impact on Global Hydrological Cycle
#
#                             Biodiversity Conservation  \
# 0                        Habitat Restoration Projects
# 1        Threatened and Endangered Species Protection
# 2                               Conservation Genetics
# 3                     Wildlife Corridor Establishment
# 4                              Marine Protected Areas
# 5   Indigenous Knowledge in Biodiversity Conservation
# 6                      Sustainable forestry Practices
# 7                         Invasive Species Management
# 8                         Protected Area Connectivity
# 9                      Conservation Breeding Programs
# 10           Community-Based Conservation Initiatives
# 11                       Climate-Resilient Ecosystems
# 12      Impact of Climate Change on Species Migration
# 13                 Eco-friendly Agriculture Practices
# 14                  Conservation of Migratory Species
# 15                    Conservation Finance Mechanisms
# 16  Role of Citizen Science in Biodiversity Monito...
# 17                  Biodiversity Hotspot Preservation
# 18                              Rewilding Initiatives
# 19                        Conservation of Pollinators
# 20                             Coral Reef Restoration
# 21           Conservation through Sustainable Tourism
# 22               Conservation Education and Awareness
# 23                     Genetic Diversity Conservation
# 24             Conservation and Sustainable Fisheries
# 25  Integrated Conservation and Development Projec...
# 26             Conservation of Microbial Biodiversity
# 27                    Conservation of Endemic Species
# 28                       Conservation Policy Advocacy
# 29      Role of Technology in Biodiversity Monitoring
#
#                                Ocean Acidification  \
# 0                            Impact on Coral Reefs
# 1               Acidification Effects on Shellfish
# 2                      Changes in Marine Food Webs
# 3                  Carbonate Ion Saturation Levels
# 4          Acidification and Marine Microorganisms
# 5        Ocean Acidification Monitoring Techniques
# 6                   Impact on Commercial Fisheries
# 7                 Influence on Marine Biodiversity
# 8                Acidification Effects on Plankton
# 9   Role of Ocean Acidification in Coral Bleaching
# 10               Acidification and Fish Physiology
# 11    Economic Consequences of Ocean Acidification
# 12          Acidification and Calcifying Organisms
# 13        Ocean Acidification Research Initiatives
# 14                  Acidification in Polar Regions
# 15                    Impact on Larval Development
# 16    Acidification Effects on Deep-Sea Ecosystems
# 17  Role of Alkalinity in Mitigating Acidification
# 18          Ocean Acidification and Climate Models
# 19             Acidification Effects on Seagrasses
# 20           Ocean Acidification and Coral Disease
# 21            Acidification and Coastal Ecosystems
# 22                Impact on Pteropods and Mollusks
# 23    Ocean Acidification and Carbon Sequestration
# 24           Acidification Effects on Foraminifera
# 25         Ocean Acidification and Shell Integrity
# 26    Acidification and Ocean Circulation Patterns
# 27            Carbonate Compensation Depth Changes
# 28             Acidification Mitigation Strategies
# 29                                             NaN
#
#                      Climate Resilient Infrastructure  \
# 0                           Resilient urban planning
# 1                      Infrastructure Risk Assessment
# 2                          Flood-Resistant building s
# 3            Climate-Resilient Transportation Systems
# 4                         Green Infrastructure Design
# 5                      Seawall and Coastal Protection
# 6                               Stormwater Management
# 7                       Adaptive Water Supply Systems
# 8                              Resilient Energy Grids
# 9                           Climate-Resilient Housing
# 10                           Heat-Resistant Pavements
# 11                     Resilience of Bridges and Dams
# 12        Climate-Adaptive Agriculture Infrastructure
# 13               Resilient Telecommunication Networks
# 14          Infrastructure for Extreme Weather Events
# 15              Integration of Nature-Based Solutions
# 16                     Climate-Resilient Data Centers
# 17                    Resilient Healthcare Facilities
# 18             Drought-Resilient Water Infrastructure
# 19              Resilience in Critical Infrastructure
# 20     Climate-Proofing Transportation Infrastructure
# 21                  Infrastructure for Sea Level Rise
# 22                Fire-Resistant Construction Methods
# 23                       Resilient Wastewater Systems
# 24            Infrastructure for Landslide Mitigation
# 25                   Climate-Resilient Airport Design
# 26           Resilience in Educational Infrastructure
# 27              Infrastructure for Melting Permafrost
# 28  Resilient Industrial and Manufacturing Facilities
# 29           Climate-Resilient Tourism Infrastructure
#
#            Greenhouse Gas Emission Reduction  \
# 0                Renewable Energy Transition
# 1                 Energy Efficiency Measures
# 2           carbon capture and Storage (CCS)
# 3       Sustainable Transportation Solutions
# 4   Afforestation and Reforestation Projects
# 5      Methane Emission Reduction Strategies
# 6                  Green building  Standards
# 7                Livestock Methane Reduction
# 8           Low-Carbon Agriculture Practices
# 9               Waste-to-Energy Technologies
# 10             Sustainable Land Use Planning
# 11       Adoption of Climate-Resilient Crops
# 12          Eco-friendly packaging Solutions
# 13  Green Finance for GHG Reduction Projects
# 14    Decentralized Renewable Energy Systems
# 15      Energy Conservation in Manufacturing
# 16          Climate-Resilient Infrastructure
# 17      Carbon Trading and Market Mechanisms
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
#
#               Climate Change Adaptation Strategies  \
# 0                       Resilient Water Management
# 1                          Coastal Zone Protection
# 2        Early Warning Systems for Extreme Weather
# 3                       Ecosystem-Based Adaptation
# 4          Climate-Resilient Agriculture Practices
# 5               Infrastructure Resilience Planning
# 6                       Community-Based Adaptation
# 7                         Health Sector Adaptation
# 8               Indigenous Knowledge in Adaptation
# 9                Climate-Resilient building  Codes
# 10                      Adaptive Forest Management
# 11                Sustainable Fisheries Management
# 12       Climate-Resilient Transportation Planning
# 13                 Climate-Adaptive Energy Systems
# 14                   Climate-Resilient Livelihoods
# 15             Adaptive Social Protection Programs
# 16           Climate-Smart Disaster Risk Reduction
# 17        Integrated Climate-Resilient Development
# 18              Adaptive Water Resource Management
# 19                    Resilient Healthcare Systems
# 20          Climate-Adaptive Technology Innovation
# 21                Community-Led Climate Adaptation
# 22              Climate-Resilient Tourism Planning
# 23             Financial Mechanisms for Adaptation
# 24             Climate-Adaptive Education Programs
# 25  Adaptive Strategies for Indigenous Communities
# 26     Climate-Resilient Biodiversity Conservation
# 27           Localized Climate Change Action Plans
# 28                                             NaN
# 29                                             NaN
#
#                         Clean Energy Transition  \
# 0                  Renewable Energy Integration
# 1                     Transition to Solar Power
# 2                       Adoption of Wind Energy
# 3                         Hydropower Generation
# 4               Biomass and Bioenergy Solutions
# 5                Tidal and Wave Energy Projects
# 6               Transitioning to Clean Hydrogen
# 7                   Energy Storage Technologies
# 8                  Decentralized Energy Systems
# 9                    Energy Efficiency Measures
# 10              Transitioning from Fossil Fuels
# 11                 Distributed Energy Resources
# 12                    smart grid Implementation
# 13               Sustainable Biofuel Production
# 14                    Green building  Standards
# 15            Eco-friendly Industrial Processes
# 16  Sustainable Water and Wastewater Management
# 17      Green Finance for Clean Energy Projects
# 18   Behavior Change Campaigns for Clean Energy
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#                            Sustainable Transportation  \
# 0            electrification of Public Transportation
# 1                       Adoption of Electric Vehicles
# 2                       Green Urban Mobility Planning
# 3               Development of Bicycle Infrastructure
# 4                           Eco-friendly Urban Design
# 5                          Low-Emission Public Fleets
# 6                       Sustainable aviation Biofuels
# 7                Eco-friendly Transportation Policies
# 8         Integration of Smart Transportation Systems
# 9              Carpooling and Ridesharing Initiatives
# 10          Development of Pedestrian-Friendly Cities
# 11               Sustainable Rail and Transit Systems
# 12                  Implementation of High-Speed Rail
# 13              Green Shipping and Maritime Transport
# 14          Eco-friendly Last-Mile Delivery Solutions
# 15               Incentives for Sustainable Commuting
# 16                              Green Urban Logistics
# 17     Development of Multi-Modal Transportation Hubs
# 18                            Smart Parking Solutions
# 19               Sustainable Transportation Education
# 20        Promotion of Eco-friendly Commuting Options
# 21                  Eco-conscious Car Rental Services
# 22          Bike-Sharing and Scooter-Sharing Programs
# 23             Adoption of Green Vehicle Technologies
# 24  Integration of Renewable Energy in Transportation
# 25   Sustainable Infrastructure for Electric Vehicles
# 26     Use of Sustainable Materials in Transportation
# 27                    Reduction of Traffic Congestion
# 28        Green Transportation Finance and Investment
# 29                                                NaN
#
#                       circular Economy Initiatives  \
# 0           Adoption of Sustainable Product Design
# 1                   Closed-Loop Material Recycling
# 2                     circular packaging Solutions
# 3                    circular Fashion and Textiles
# 4                 Reusable and Recyclable Plastics
# 5        Extended Producer Responsibility Programs
# 6                Product Life Extension Strategies
# 7                  E-Waste Recycling and Upcycling
# 8        Eco-friendly Waste-to-Energy Technologies
# 9                   circular Agriculture Practices
# 10   circular building  and Construction Materials
# 11       Sustainable Water Use in circular Economy
# 12                  Eco-friendly Consumer Behavior
# 13                circular Supply Chain Management
# 14    Integration of circular Design in Industries
# 15            Adoption of circular Business Models
# 16             Collaborative Consumption Platforms
# 17        circular Economy Education and Awareness
# 18               Green Public Procurement Policies
# 19            circular Approaches in Manufacturing
# 20              Urban Mining for Resource Recovery
# 21              Eco-labeling for circular Products
# 22               Remanufacturing and Refurbishment
# 23               Sustainable Product Certification
# 24             circular Economy Finance Mechanisms
# 25                   Reduction of Single-Use Items
# 26                circular Economy in Food Systems
# 27  Sustainable Technologies for Resource Recovery
# 28            circular Solutions for Textile Waste
# 29     circular Approaches in Electronics Industry
#
#                            Climate Justice and Equity  \
# 0                      Environmental Justice Advocacy
# 1                Fair Distribution of Climate Impacts
# 2                 Indigenous Rights in Climate Action
# 3                      Access to Clean Energy for All
# 4                 Gender Equality in Climate Policies
# 5                   Climate Refugees and Displacement
# 6                Fair Distribution of Climate Finance
# 7               Inclusion of Marginalized Communities
# 8               Intersectionality in Climate Activism
# 9                    Community-Led Climate Adaptation
# 10                Recognition of Historical Emissions
# 11      Addressing Climate Injustices in Policymaking
# 12                     Environmental Racism Awareness
# 13              Participation of Indigenous Knowledge
# 14       Climate Education for Vulnerable Communities
# 15                  Indigenous Land Rights Protection
# 16              Empowerment of Vulnerable Populations
# 17              Access to Climate Information for All
# 18              Equity in Global Climate Negotiations
# 19              Recognition of Indigenous Stewardship
# 20  Climate-Resilient Infrastructure in Underserve...
# 21             Reducing Disparities in Climate Impact
# 22               Localized Climate Action Initiatives
# 23                          Fair Access to Green Jobs
# 24  Recognition of Cultural Heritage in Climate Po...
# 25                Inclusive Decision-Making Processes
# 26            Addressing Climate Injustices in Health
# 27             Solidarity in Global Climate Movements
# 28                        Recognition of Climate Debt
# 29     Equity in Sustainable Development Goals (SDGs)
#
#                            carbon capture and Storage  \
# 0                     Direct Air Capture Technologies
# 1           Enhanced Oil Recovery with carbon capture
# 2               Geological Storage of Captured Carbon
# 3       carbon capture Utilization and Storage (CCUS)
# 4                     Carbon Sequestration in Forests
# 5   Bioenergy with carbon capture and Storage (BECCS)
# 6                  Ocean-Based carbon capture Methods
# 7              carbon capture in Industrial Processes
# 8                   Carbon Mineralization and Storage
# 9               Microbial carbon capture Technologies
# 10                   carbon capture from Power Plants
# 11               carbon capture and Utilization (CCU)
# 12               Leak Detection and Monitoring in CCS
# 13        International Collaboration on CCS Research
# 14           Regulatory Frameworks for carbon capture
# 15                Funding Mechanisms for CCS Projects
# 16            Public Perception and Acceptance of CCS
# 17      Integration of CCS in Sustainable Development
# 18                        CCS in Developing Countries
# 19               Policy Incentives for CCS Deployment
# 20                    Technological Innovation in CCS
# 21                      carbon capture Infrastructure
# 22                        carbon capture Retrofitting
# 23                         Financial Viability of CCS
# 24           CCS in the Context of Climate Mitigation
# 25          Carbon Dioxide Removal (CDR) Technologies
# 26           CCS in Conjunction with Renewable Energy
# 27              carbon capture in the Cement Industry
# 28          CCS for Greenhouse Gas Emission Reduction
# 29                                                NaN
#
#                      International Climate agreement
# 0                      Paris Agreement Implementation
# 1          Nationally Determined Contributions (NDCs)
# 2              Global Greenhouse Gas Emission Targets
# 3                         Climate Finance Commitments
# 4                     Adaptation and Resilience Goals
# 5              Technology Transfer for Climate Action
# 6       Monitoring, Reporting, and Verification (MRV)
# 7                            Carbon Market Mechanisms
# 8                           Loss and Damage Mechanism
# 9           Capacity building  for Developing Nations
# 10                    Global Climate Funds Allocation
# 11        Climate Justice in International Agreements
# 12       Climate Diplomacy and Negotiation Strategies
# 13                      Transboundary Climate Impacts
# 14                        Regional Climate Agreements
# 15              Multilateral Environmental Agreements
# 16  United Nations Framework Convention on Climate...
# 17   Intergovernmental Panel on Climate Change (IPCC)
# 18        Climate Action in International Development
# 19                          Global Climate Governance
# 20            Cross-Border Climate Migration Policies
# 21    Equity and Fairness in International Agreements
# 22    International Collaboration on Climate Research
# 23                   Global Carbon Budget Allocations
# 24             Climate Agreements and Global Security
# 25                       Bilateral Climate Agreements
# 26      Role of Non-Governmental Organizations (NGOs)
# 27   United Nations Climate Change Conferences (COPs)
# 28  Indigenous Rights and Inclusion in Global Agre...
# 29  Climate Agreements and Sustainable Development...

# %%
subs_climatechg.columns
# Out:
# Index(['Global Warming', 'Sea Level Rise', 'Carbon Footprint Reduction',
#        'Sustainable Agriculture Practices', 'Deforestation and Reforestation',
#        'Melting Ice Caps and Glaciers', 'Extreme Weather Events',
#        'Biodiversity Conservation', 'Ocean Acidification',
#        'Climate Resilient Infrastructure', 'Greenhouse Gas Emission Reduction',
#        'Climate Change Adaptation Strategies', 'Clean Energy Transition',
#        'Sustainable Transportation', 'circular Economy Initiatives',
#        'Climate Justice and Equity', 'carbon capture and Storage',
#        'International Climate agreement '],
#       dtype='object')

# %%
GW = subs_climatechg['Global Warming'].dropna().values
SLR = subs_climatechg['Sea Level Rise'].dropna().values
CFR = subs_climatechg['Carbon Footprint Reduction'].dropna().values
SAP = subs_climatechg['Sustainable Agriculture Practices'].dropna().values
DAR = subs_climatechg['Deforestation and Reforestation'].dropna().values
MCG = subs_climatechg['Melting Ice Caps and Glaciers'].dropna().values
EWE = subs_climatechg['Extreme Weather Events'].dropna().values
BC = subs_climatechg['Biodiversity Conservation'].dropna().values
OA = subs_climatechg['Ocean Acidification'].dropna().values
CRI = subs_climatechg['Climate Resilient Infrastructure'].dropna().values
GER = subs_climatechg['Greenhouse Gas Emission Reduction'].dropna().values
CAS = subs_climatechg['Climate Change Adaptation Strategies'].dropna().values
CET = subs_climatechg['Clean Energy Transition'].dropna().values
ST = subs_climatechg['Sustainable Transportation'].dropna().values
CEI = subs_climatechg['circular Economy Initiatives'].dropna().values
CJE = subs_climatechg['Climate Justice and Equity'].dropna().values
CCS = subs_climatechg['carbon capture and Storage'].dropna().values
ICA = subs_climatechg['International Climate agreement '].dropna().values

# %%
GW
# Out:
# array(['Greenhouse Gas Emissions', 'Rising Average Global Temperatures',
#        'Impact on Polar Ice Caps', 'Ocean Temperature Increase',
#        'Extreme Weather Patterns', 'Melting Glaciers and Ice Sheets',
#        'Sea Level Rise', 'Heatwaves and Heat-Related Illnesses',
#        'Ocean Acidification', 'Shifts in Wildlife Migration Patterns',
#        'Disruption of Ecosystems',
#        'Effects on Agriculture and Food Security',
#        'Threats to Coral Reefs',
#        'Increased Intensity of Hurricanes/Cyclones',
#        'Impact on Arctic and Antarctic Wildlife',
#        'Permafrost Thaw and Release of Methane',
#        'Rising Sea Surface Temperatures', 'Threats to Biodiversity',
#        'Changes in Ocean Circulation', 'Impact on Coastal Communities',
#        'Spread of Vector-Borne Diseases', 'Acid Rain Formation',
#        'Changes in Weather Extremes', 'Altered Patterns of Snowfall',
#        'Risks to Low-Lying Islands', 'Ocean Current Changes',
#        'Shifts in Wildlife Habitats',
#        'Challenges for Indigenous Communities'], dtype=object)

# %%
def topic_allocation_clmtactn(sub_topic):
    if pd.isnull(sub_topic):
        return "NA"
    if any(keyword in sub_topic for keyword in GW):
        return "Global Warming"
    elif any(keyword in sub_topic for keyword in SLR):
        return "Sea Level Rise"
    elif any(keyword in sub_topic for keyword in CFR):
        return "Carbon Footprint Reduction"
    elif any(keyword in sub_topic for keyword in SAP):
        return "Sustainable Agriculture Practices"
    elif any(keyword in sub_topic for keyword in DAR):
        return "Deforestation and Reforestation"
    elif any(keyword in sub_topic for keyword in MCG):
        return "Melting Ice Caps and Glaciers"
    elif any(keyword in sub_topic for keyword in EWE):
        return "Extreme Weather Events"
    elif any(keyword in sub_topic for keyword in BC):
        return "Biodiversity Conservation"
    elif any(keyword in sub_topic for keyword in OA):
        return "Ocean Acidification"
    elif any(keyword in sub_topic for keyword in CRI):
        return "Climate Resilient Infrastructure"
    elif any(keyword in sub_topic for keyword in GER):
        return "Greenhouse Gas Emission Reduction'"
    elif any(keyword in sub_topic for keyword in CAS):
        return "Climate Change Adaptation Strategies"
    elif any(keyword in sub_topic for keyword in CET):
        return "Clean Energy Transition"
    elif any(keyword in sub_topic for keyword in ST):
        return "Sustainable Transportation"
    elif any(keyword in sub_topic for keyword in CEI):
        return "circular Economy Initiatives"
    elif any(keyword in sub_topic for keyword in CJE):
        return "Climate Justice and Equity"
    elif any(keyword in sub_topic for keyword in CCS):
        return "carbon capture and Storage"
    elif any(keyword in sub_topic for keyword in ICA):
        return "International Climate Agreements"
    else:
        return "Other"

# %%
climate_action_df['Topic'] = climate_action_df['Assigned Subtopic(Preprocessed)'].apply(topic_allocation_clmtactn)

# %%
climate_action_df_striped = climate_action_df[climate_action_df['Topic'] != 'NA']

# %%
climate_action_df_striped = climate_action_df_striped[['Question', 'Answer', 'Macrotopic ', 'Topic',
                                                   'Assigned Subtopic(Preprocessed)', 'Source Url']]

# %%
climate_action_df_striped.rename(columns={'Assigned Subtopic(Preprocessed)': 'Subtopic'}, inplace=True)
climate_action_df_striped = climate_action_df_striped.reset_index(drop=True)

# %%
climate_action_df_striped
# Out:
#                                               Question  \
# 0    Why is sustainability risk gaining importance ...
# 1    Why is environmental risk, particularly climat...
# 2    How does climate change impact financial perfo...
# 3    How do EU sustainability policies address clim...
# 4    How are climate policy goals related to sustai...
# ..                                                 ...
# 543  How can scenario planning be implemented in th...
# 544  What is the main purpose of the digital platfo...
# 545  How does Get Together contribute to urban soci...
# 546  In what way can storytelling be used to mobili...
# 547  How do Stile et al. (2014) advocate for the pr...
#
#                                                 Answer      Macrotopic   \
# 0    Sustainability risk, or ESG risk, is gaining i...  Climate Action
# 1    Environmental risk, especially climate change,...  Climate Action
# 2    Studies and reports indicate that climate chan...  Climate Action
# 3    EU sustainability policies address climate cha...  Climate Action
# 4    Climate policy goals are in line with sustaina...  Climate Action
# ..                                                 ...              ...
# 543  Scenario planning can be effectively implement...  Climate Action
# 544  The main purpose of the digital platform Get T...  Climate Action
# 545  Get Together contributes to urban social parti...  Climate Action
# 546  Storytelling can be a powerful tool in partici...  Climate Action
# 547  Stile et al. (2014) argue that promoting publi...  Climate Action
#
#                                   Topic  \
# 0            carbon capture and Storage
# 1                Extreme Weather Events
# 2                Extreme Weather Events
# 3    Greenhouse Gas Emission Reduction'
# 4      International Climate Agreements
# ..                                  ...
# 543          Sustainable Transportation
# 544                               Other
# 545          Climate Justice and Equity
# 546          Climate Justice and Equity
# 547           Biodiversity Conservation
#
#                                               Subtopic  \
# 0                           Financial Viability of CCS
# 1                  Intense Rainfall and Flash Flooding
# 2                        Changes in Windstorm Patterns
# 3             Green Finance for GHG Reduction Projects
# 4               Global Greenhouse Gas Emission Targets
# ..                                                 ...
# 543                              Green Urban Logistics
# 544                           Resilient Urban Planning
# 545               Localized Climate Action Initiatives
# 546               Localized Climate Action Initiatives
# 547  Role of Citizen Science in Biodiversity Monito...
#
#                                             Source Url
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 543  https://www.sciencedirect.com/science/article/...
# 544  https://www.sciencedirect.com/science/article/...
# 545  https://www.sciencedirect.com/science/article/...
# 546  https://www.sciencedirect.com/science/article/...
# 547  https://www.sciencedirect.com/science/article/...
#
# [548 rows x 6 columns]

# %%
climate_action_df_striped.to_csv('Climate Change for SUPERCLEANED dataset 23-3-2024.csv')

# %%
climate_action_df.to_csv('Unstriped Climate Change for SUPERCLEANED dataset 23-3-2024.csv')
